# %% [markdown]
# # 영산강 광산보 주별 데이터, RNN 적용

# %% [markdown]
# **필수 라이브러리**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# **matplotlib 한글 설정**
#
# - 운영체제에 따른 한글 지원 설정. 윈도우, 우분투, 구글 코랩 지원.
# - 참고: [matplotlib에서 한글 지원하기](https://github.com/codingalzi/datapy/blob/master/matplotlib-korean.md)

# %%
import platform

if platform.system() == 'Windows': # 윈도우
    from matplotlib import font_manager, rc
    font_path = "C:/Windows/Fonts/NGULIM.TTF"
    font = font_manager.FontProperties(fname=font_path).get_name()
    rc('font', family=font)
elif platform.system() == 'Linux': # 우분투 또는 구글 코랩
    # please run the following commented out codes just once
#     if 'google.colab' in str(get_ipython()):
#         !apt-get install -y fonts-nanum*
#     else:
#         !sudo apt-get install -y fonts-nanum*
#     !fc-cache -fv
    
    applyfont = "NanumBarunGothic"
    import matplotlib.font_manager as fm
    if not any(map(lambda ft: ft.name == applyfont, fm.fontManager.ttflist)):
        fm.fontManager.addfont("/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf")
    plt.rc("font", family=applyfont)
    plt.rc("axes", unicode_minus=False)

# %% [markdown]
# ## 데이터 준비

# %% [markdown]
# **데이터 저장소**
#
# 데이터 원본 파일 저장소는 다음과 같다.

# %%
base_url = "https://github.com/codingalzi/water-data/raw/master/reservoirs/"

# %% [markdown]
# **영산강(엑셀) 자료를 데이터프레임으로 불러오기**

# %% [markdown]
# 모든 지역의 데이터 불러오기: 평동천, 광산, 장성천2, 문평천, 영산포2, 함평, 무안2
#
# - `header=0`: 0번 행을 header로 지정, 즉 열 인덱스로 사용.
# - `sheet_name=None`: 모든 워크시트 가져오기. 워크시트별로 하나의 df 생성. 반환값은 사전.
# - `na_values=0`: 0으로 입력된 값도 결측치로 처리
# - `index_col=1`: 측정일을 행 인덱스로 사용
# - `parse_dates=True`: 행 인덱스로 사용되는 날짜 대상 파싱 실행

# %%
# 주의: 엑셀파일을 불러오기 위해 아래 모듈이 필요하다.

# !pip install openpyxl

# %%
yeongsan = pd.read_excel(base_url+"Yeongsan_weekly_total.xlsx",
                            header=0, 
                            sheet_name=None,
                            na_values=0,
                            index_col=1, 
                            parse_dates=True)

# %% [markdown]
# 포함된 보(reservoir)의 지역명은 다음과 같다.

# %%
locations = yeongsan.keys()
locations
# Out:
# dict_keys(['1_평동천', '2_광산', '3_장성천2', '4_문평천', '5_영산포2', '6_함평', '7_무안2'])

# %% [markdown]
# **주요 특성**

# %% [markdown]
# 수온, BOD, COD, TN, TP, 유량 등 6개의 주요 특성만을 이용하여 클로로필-A 예측하려 한다.
# 원 데이터셋에 포함된 19개의 특성은 다음과 같다.

# %%
list(yeongsan['1_평동천'].columns)
# Out:
# ['측정소명',
#  '회차',
#  '수온(℃)',
#  'DO(㎎/L)',
#  'BOD(㎎/L)',
#  'COD(㎎/L)',
#  '클로로필 a(㎎/㎥)',
#  'TN(㎎/L)',
#  'TP(㎎/L)',
#  'TOC(㎎/L)',
#  '수소이온농도',
#  '전기전도도(μS/㎝)',
#  '용존총질소(㎎/L)',
#  '암모니아성 질소(㎎/L)',
#  '질산성 질소(㎎/L)',
#  '용존총인(㎎/L)',
#  '인산염인(㎎/L)',
#  'SS(㎎/L)',
#  '유량(㎥/s)']

# %% [markdown]
# 주요 특성 6개와 타깃으로 사용될 특성인 클로로필-A를 별도로 지정한다.

# %%
features_important = ['수온(℃)', 'BOD(㎎/L)', 'COD(㎎/L)', 'TN(㎎/L)', 'TP(㎎/L)', '유량(㎥/s)', '클로로필 a(㎎/㎥)']

# %% [markdown]
# - 입력데이터셋 특성 6개

# %%
six_features = features_important[:6]

# %% [markdown]
# * 타깃 특성: 클로로필-A

# %%
target_feature = features_important[-1]

# %% [markdown]
# **지역별 데이터**

# %% [markdown]
# 지역별 데이터셋 크기는 다음과 같다.

# %%
total_data = 0

for loc in locations:
    ys_loc = yeongsan[loc]
    total_data += ys_loc.shape[0]
    print(f"{loc}: \t{ys_loc.shape}")
    
print("총 데이터수:", total_data)
# Out:
# 1_평동천: 	(440, 19)
# 2_광산: 	(510, 19)
# 3_장성천2: 	(435, 19)
# 4_문평천: 	(435, 19)
# 5_영산포2: 	(456, 19)
# 6_함평: 	(456, 19)
# 7_무안2: 	(534, 19)
# 총 데이터수: 3266

# %% [markdown]
# **지역별 데이터 분포**

# %% [markdown]
# 모든 지역에서 유량과 클로로필-A 특성에서 일부 결측지가 존재한다.
#
# - 광산 데이터셋이 가장 크면서 가장 적은 유량 결측치를 가진다.

# %%
for loc in locations:
    print(f"\n=== {loc} ===\n")
    ys_loc = yeongsan[loc][features_important]
    ys_loc.info()
# Out:
# === 1_평동천 ===
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 440 entries, 2012-06-05 to 2022-06-27
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   수온(℃)        440 non-null    float64
#  1   BOD(㎎/L)     440 non-null    float64
#  2   COD(㎎/L)     440 non-null    float64
#  3   TN(㎎/L)      440 non-null    float64
#  4   TP(㎎/L)      440 non-null    float64
#  5   유량(㎥/s)      437 non-null    float64
#  6   클로로필 a(㎎/㎥)  424 non-null    float64
# dtypes: float64(7)
# memory usage: 27.5 KB
#
# === 2_광산 ===
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 510 entries, 2012-01-04 to 2021-12-20
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   수온(℃)        510 non-null    float64
#  1   BOD(㎎/L)     510 non-null    float64
#  2   COD(㎎/L)     510 non-null    float64
#  3   TN(㎎/L)      510 non-null    float64
#  4   TP(㎎/L)      510 non-null    float64
#  5   유량(㎥/s)      508 non-null    float64
#  6   클로로필 a(㎎/㎥)  510 non-null    float64
# dtypes: float64(7)
# memory usage: 31.9 KB
#
# === 3_장성천2 ===
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 435 entries, 2012-06-07 to 2022-06-29
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   수온(℃)        435 non-null    float64
#  1   BOD(㎎/L)     435 non-null    float64
#  2   COD(㎎/L)     435 non-null    float64
#  3   TN(㎎/L)      435 non-null    float64
#  4   TP(㎎/L)      435 non-null    float64
#  5   유량(㎥/s)      426 non-null    float64
#  6   클로로필 a(㎎/㎥)  419 non-null    float64
# dtypes: float64(7)
# memory usage: 27.2 KB
#
# === 4_문평천 ===
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 435 entries, 2012-06-07 to 2022-06-29
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   수온(℃)        435 non-null    float64
#  1   BOD(㎎/L)     435 non-null    float64
#  2   COD(㎎/L)     435 non-null    float64
#  3   TN(㎎/L)      435 non-null    float64
#  4   TP(㎎/L)      435 non-null    float64
#  5   유량(㎥/s)      426 non-null    float64
#  6   클로로필 a(㎎/㎥)  419 non-null    float64
# dtypes: float64(7)
# memory usage: 27.2 KB
#
# === 5_영산포2 ===
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 456 entries, 2012-01-10 to 2022-06-28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   수온(℃)        456 non-null    float64
#  1   BOD(㎎/L)     456 non-null    float64
#  2   COD(㎎/L)     456 non-null    float64
#  3   TN(㎎/L)      456 non-null    float64
#  4   TP(㎎/L)      456 non-null    float64
#  5   유량(㎥/s)      451 non-null    float64
#  6   클로로필 a(㎎/㎥)  456 non-null    float64
# dtypes: float64(7)
# memory usage: 28.5 KB
#
# === 6_함평 ===
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 456 entries, 2012-01-10 to 2022-06-28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   수온(℃)        456 non-null    float64
#  1   BOD(㎎/L)     456 non-null    float64
#  2   COD(㎎/L)     456 non-null    float64
#  3   TN(㎎/L)      456 non-null    float64
#  4   TP(㎎/L)      456 non-null    float64
#  5   유량(㎥/s)      449 non-null    float64
#  6   클로로필 a(㎎/㎥)  456 non-null    float64
# dtypes: float64(7)
# memory usage: 28.5 KB
#
# === 7_무안2 ===
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 534 entries, 2012-01-05 to 2022-06-28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   수온(℃)        534 non-null    float64
#  1   BOD(㎎/L)     534 non-null    float64
#  2   COD(㎎/L)     534 non-null    float64
#  3   TN(㎎/L)      534 non-null    float64
#  4   TP(㎎/L)      534 non-null    float64
#  5   유량(㎥/s)      229 non-null    float64
#  6   클로로필 a(㎎/㎥)  534 non-null    float64
# dtypes: float64(7)
# memory usage: 33.4 KB

# %% [markdown]
# **광산 지역 데이터**

# %%
kwangsan = yeongsan['2_광산'][features_important]

# %%
kwangsan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 510 entries, 2012-01-04 to 2021-12-20
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   수온(℃)        510 non-null    float64
#  1   BOD(㎎/L)     510 non-null    float64
#  2   COD(㎎/L)     510 non-null    float64
#  3   TN(㎎/L)      510 non-null    float64
#  4   TP(㎎/L)      510 non-null    float64
#  5   유량(㎥/s)      508 non-null    float64
#  6   클로로필 a(㎎/㎥)  510 non-null    float64
# dtypes: float64(7)
# memory usage: 31.9 KB

# %% [markdown]
# 결측치를 포함한 데이터 2개는 제거한다.

# %%
kwangsan = kwangsan.dropna()

# %% [markdown]
# **특성 정규화**

# %% [markdown]
# 모든 특성을 정규화한다.
#
# 먼저 특성별 평균값과 표준편차를 계산한다.

# %%
kwangsan_mean = kwangsan.mean(axis=0)
kwangsan_std = kwangsan.std(axis=0)

# %% [markdown]
# 평균은 0, 표준편차는 1로 변환한다.

# %%
kwangsan = (kwangsan - kwangsan_mean)/kwangsan_std
kwangsan
# Out:
#                수온(℃)  BOD(㎎/L)  COD(㎎/L)   TN(㎎/L)   TP(㎎/L)   유량(㎥/s)  \
# 년/월/일
# 2012-01-04 -1.669834 -0.126796 -0.403615  1.064816  4.079187 -0.477342
# 2012-01-09 -1.441486 -0.190132 -0.246860  2.530872  6.795254 -0.426468
# 2012-01-18 -1.416114  1.076584  0.497731  3.238200  6.380299 -0.478248
# 2012-01-27 -1.644462  0.379890  0.889620  2.218704  0.646380 -0.397462
# 2012-01-30 -1.441486  0.886577  0.497731  1.588710  4.182925 -0.450120
# ...              ...       ...       ...       ...       ...       ...
# 2021-11-22 -0.502721 -0.570147 -0.286049 -0.375304 -0.664499 -0.529255
# 2021-11-29 -0.718383 -0.633483 -0.403615  0.371634  0.363457 -0.545875
# 2021-12-06 -1.010161 -0.063460 -0.756316 -0.173480  0.221995 -0.396050
# 2021-12-13 -0.870615  0.316554 -0.050915  0.378707 -0.089221 -0.464078
# 2021-12-20 -1.251196  0.506562 -0.481993  0.824324 -0.400437 -0.408409
#
#             클로로필 a(㎎/㎥)
# 년/월/일
# 2012-01-04    -0.669352
# 2012-01-09    -0.669352
# 2012-01-18     0.421764
# 2012-01-27     0.657466
# 2012-01-30     0.098666
# ...                 ...
# 2021-11-22     0.040403
# 2021-11-29    -0.581957
# 2021-12-06    -0.216486
# 2021-12-13     0.201952
# 2021-12-20    -0.372738
#
# [508 rows x 7 columns]

# %% [markdown]
# ## 시계열 데이터 분석

# %% [markdown]
# 시간의 흐름을 고려해서 시계열(timeseries) 데이터로 처리한다.

# %% [markdown]
# **날짜별로 정렬**

# %% [markdown]
# 먼저 날짜별로 정렬한다.

# %%
kwangsan = kwangsan.sort_index()

# %% [markdown]
# **훈련셋과 테스트셋 지정**

# %% [markdown]
# 훈련셋, 검증셋, 테스트셋을 7:2:1의 비율로 나눈다.
# 단, 테스트셋은 날짜를 기준으로 나중에 측정된 데이터를 이용한다.

# %%
train_size = int(kwangsan.shape[0] * 0.7)
val_size = int(kwangsan.shape[0] * 0.2)

# %% [markdown]
# - 훈련셋

# %%
train_set = kwangsan[six_features][:train_size]
train_targets = kwangsan[target_feature][:train_size]

# %% [markdown]
# - 검증셋

# %%
val_set = kwangsan[six_features][train_size : train_size + val_size]
val_targets = kwangsan[target_feature][train_size : train_size + val_size]

# %% [markdown]
# - 테스트셋

# %%
test_set = kwangsan[six_features][train_size + val_size:]
test_targets = kwangsan[target_feature][train_size + val_size:]

# %% [markdown]
# **시계열 데이터로 변환**

# %%
import tensorflow as tf

# %% [markdown]
# 시계열 데이터 샘플을 `sequence_length` 만큼의 타임 스텝(time step)로
# 구성한다.
# 예측값은 미래가 아닌 현재의 클로로필-A 수치로 지정한다.
#
# - 타임 스텝 크기: 8(두 달)
# - 배치 크기: 32
# - `shuffle=True`: 구성된 시계열 샘플 뒤섞기

# %%
sequence_length=8  # 타임 스텝 크기

train_dataset = tf.keras.utils.timeseries_dataset_from_array(
    train_set,
    targets=train_targets[sequence_length-1:],
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=32)

val_dataset = tf.keras.utils.timeseries_dataset_from_array(
    val_set,
    targets=val_targets[sequence_length-1:],
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=32)

test_dataset = tf.keras.utils.timeseries_dataset_from_array(
    test_set,
    targets=test_targets[sequence_length-1:],
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=32)

# %% [markdown]
# 입력 데이터셋의 배치의 모양은 `(32, sequence_length, 6)`이다.

# %%
for samples, targets in train_dataset:
    print("samples shape:", samples.shape)
    print("targets shape:", targets.shape)
    break
# Out:
# samples shape: (32, 8, 6)
# targets shape: (32,)

# %% [markdown]
# **GRU 모델 사용**

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# - 훈련 중 `dropout_rate` 만큼의 드랍아웃 적용
# - 조기종료 실행. (검증셋에 대한 성능이 더 이상 좋아지지 않는 경우)
# - 성능이 별로 좋지 않음.
# - 보다 많은 특성을 사용하는 것이 나을 수도 있음

# %%
dropout_rate = 0.5

inputs = keras.Input(shape=(sequence_length, len(features_important)-1))
x = layers.GRU(48, recurrent_dropout=dropout_rate, return_sequences=True)(inputs)
x = layers.GRU(48, recurrent_dropout=dropout_rate)(x)
x = layers.Dropout(dropout_rate)(x)
outputs = layers.Dense(1)(x)
model = keras.Model(inputs, outputs)
  
early_stopping_cb = keras.callbacks.EarlyStopping(
        monitor="val_mae", patience=20, restore_best_weights=True)

callbacks = [
    keras.callbacks.ModelCheckpoint("kwangsan_gru.keras",
                                    save_best_only=True),
    early_stopping_cb
]

model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])

history = model.fit(train_dataset,
                    epochs=100,
                    validation_data=val_dataset,
                    callbacks=callbacks)

model = keras.models.load_model("kwangsan_gru.keras") 

print(f"Test MAE: {model.evaluate(test_dataset)[1]:.2f}")
# Out:
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 11/11 [==============================] - 4s 88ms/step - loss: 0.6709 - mae: 0.6440 - val_loss: 1.3146 - val_mae: 0.8216
# Epoch 2/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.5898 - mae: 0.6059 - val_loss: 1.2644 - val_mae: 0.8072
# Epoch 3/100
# 11/11 [==============================] - 1s 58ms/step - loss: 0.5781 - mae: 0.5915 - val_loss: 1.1954 - val_mae: 0.7816
# Epoch 4/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.5361 - mae: 0.5701 - val_loss: 1.1433 - val_mae: 0.7647
# Epoch 5/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.5352 - mae: 0.5812 - val_loss: 1.0706 - val_mae: 0.7356
# Epoch 6/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.4686 - mae: 0.5368 - val_loss: 1.0227 - val_mae: 0.7148
# Epoch 7/100
# 11/11 [==============================] - 1s 64ms/step - loss: 0.4974 - mae: 0.5513 - val_loss: 0.9937 - val_mae: 0.7104
# Epoch 8/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.4645 - mae: 0.5420 - val_loss: 0.9575 - val_mae: 0.6892
# Epoch 9/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.4523 - mae: 0.5232 - val_loss: 0.9311 - val_mae: 0.6741
# Epoch 10/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.4388 - mae: 0.5059 - val_loss: 0.9001 - val_mae: 0.6649
# Epoch 11/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.4180 - mae: 0.4974 - val_loss: 0.8819 - val_mae: 0.6425
# Epoch 12/100
# 11/11 [==============================] - 1s 59ms/step - loss: 0.3731 - mae: 0.4791 - val_loss: 0.8522 - val_mae: 0.6360
# Epoch 13/100
# 11/11 [==============================] - 1s 58ms/step - loss: 0.3902 - mae: 0.4804 - val_loss: 0.8451 - val_mae: 0.6389
# Epoch 14/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.3953 - mae: 0.4900 - val_loss: 0.8278 - val_mae: 0.6224
# Epoch 15/100
# 11/11 [==============================] - 1s 57ms/step - loss: 0.3995 - mae: 0.4892 - val_loss: 0.8158 - val_mae: 0.6170
# Epoch 16/100
# 11/11 [==============================] - 1s 58ms/step - loss: 0.3834 - mae: 0.4755 - val_loss: 0.8041 - val_mae: 0.6057
# Epoch 17/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.3359 - mae: 0.4538 - val_loss: 0.8054 - val_mae: 0.6092
# Epoch 18/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.3588 - mae: 0.4642 - val_loss: 0.7996 - val_mae: 0.6102
# Epoch 19/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.3470 - mae: 0.4654 - val_loss: 0.8044 - val_mae: 0.6088
# Epoch 20/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.3667 - mae: 0.4632 - val_loss: 0.7680 - val_mae: 0.5900
# Epoch 21/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.3486 - mae: 0.4554 - val_loss: 0.7570 - val_mae: 0.5848
# Epoch 22/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.3460 - mae: 0.4616 - val_loss: 0.7665 - val_mae: 0.5937
# Epoch 23/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.3418 - mae: 0.4454 - val_loss: 0.7633 - val_mae: 0.5860
# Epoch 24/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.3581 - mae: 0.4586 - val_loss: 0.7737 - val_mae: 0.5910
# Epoch 25/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.3129 - mae: 0.4388 - val_loss: 0.7722 - val_mae: 0.5868
# Epoch 26/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.3191 - mae: 0.4486 - val_loss: 0.7545 - val_mae: 0.5787
# Epoch 27/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.3408 - mae: 0.4626 - val_loss: 0.7683 - val_mae: 0.5883
# Epoch 28/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.3378 - mae: 0.4482 - val_loss: 0.7615 - val_mae: 0.5706
# Epoch 29/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.3219 - mae: 0.4449 - val_loss: 0.7572 - val_mae: 0.5676
# Epoch 30/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.3282 - mae: 0.4474 - val_loss: 0.7810 - val_mae: 0.5877
# Epoch 31/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.3295 - mae: 0.4499 - val_loss: 0.7564 - val_mae: 0.5749
# Epoch 32/100
# 11/11 [==============================] - 1s 57ms/step - loss: 0.3091 - mae: 0.4363 - val_loss: 0.7508 - val_mae: 0.5725
# Epoch 33/100
# 11/11 [==============================] - 1s 64ms/step - loss: 0.3256 - mae: 0.4441 - val_loss: 0.7323 - val_mae: 0.5627
# Epoch 34/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.3311 - mae: 0.4507 - val_loss: 0.7308 - val_mae: 0.5642
# Epoch 35/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.3340 - mae: 0.4424 - val_loss: 0.7441 - val_mae: 0.5725
# Epoch 36/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.3148 - mae: 0.4353 - val_loss: 0.7744 - val_mae: 0.5867
# Epoch 37/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.3194 - mae: 0.4359 - val_loss: 0.7502 - val_mae: 0.5840
# Epoch 38/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.3063 - mae: 0.4423 - val_loss: 0.7380 - val_mae: 0.5735
# Epoch 39/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.3123 - mae: 0.4346 - val_loss: 0.7228 - val_mae: 0.5678
# Epoch 40/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.3154 - mae: 0.4389 - val_loss: 0.7173 - val_mae: 0.5510
# Epoch 41/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.2950 - mae: 0.4157 - val_loss: 0.7405 - val_mae: 0.5676
# Epoch 42/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.3129 - mae: 0.4335 - val_loss: 0.7249 - val_mae: 0.5694
# Epoch 43/100
# 11/11 [==============================] - 1s 57ms/step - loss: 0.3065 - mae: 0.4238 - val_loss: 0.7128 - val_mae: 0.5655
# Epoch 44/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.3178 - mae: 0.4403 - val_loss: 0.7176 - val_mae: 0.5620
# Epoch 45/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.2985 - mae: 0.4134 - val_loss: 0.7195 - val_mae: 0.5621
# Epoch 46/100
# 11/11 [==============================] - 1s 60ms/step - loss: 0.3081 - mae: 0.4371 - val_loss: 0.7261 - val_mae: 0.5636
# Epoch 47/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.2975 - mae: 0.4222 - val_loss: 0.7116 - val_mae: 0.5635
# Epoch 48/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.3057 - mae: 0.4298 - val_loss: 0.7434 - val_mae: 0.5728
# Epoch 49/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.3126 - mae: 0.4292 - val_loss: 0.7177 - val_mae: 0.5582
# Epoch 50/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.2988 - mae: 0.4351 - val_loss: 0.7136 - val_mae: 0.5508
# Epoch 51/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.3076 - mae: 0.4298 - val_loss: 0.7360 - val_mae: 0.5754
# Epoch 52/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2912 - mae: 0.4224 - val_loss: 0.7276 - val_mae: 0.5658
# Epoch 53/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.3111 - mae: 0.4296 - val_loss: 0.7366 - val_mae: 0.5632
# Epoch 54/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.3055 - mae: 0.4330 - val_loss: 0.7143 - val_mae: 0.5520
# Epoch 55/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.3027 - mae: 0.4258 - val_loss: 0.7091 - val_mae: 0.5609
# Epoch 56/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.2866 - mae: 0.4186 - val_loss: 0.7272 - val_mae: 0.5638
# Epoch 57/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.2585 - mae: 0.4060 - val_loss: 0.6865 - val_mae: 0.5464
# Epoch 58/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.2772 - mae: 0.4119 - val_loss: 0.6925 - val_mae: 0.5534
# Epoch 59/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2734 - mae: 0.3971 - val_loss: 0.6934 - val_mae: 0.5548
# Epoch 60/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.2812 - mae: 0.4070 - val_loss: 0.6812 - val_mae: 0.5545
# Epoch 61/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.2875 - mae: 0.4166 - val_loss: 0.6787 - val_mae: 0.5483
# Epoch 62/100
# 11/11 [==============================] - 1s 55ms/step - loss: 0.2645 - mae: 0.4031 - val_loss: 0.6806 - val_mae: 0.5477
# Epoch 63/100
# 11/11 [==============================] - 1s 56ms/step - loss: 0.2570 - mae: 0.3984 - val_loss: 0.6831 - val_mae: 0.5591
# Epoch 64/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.3092 - mae: 0.4243 - val_loss: 0.7046 - val_mae: 0.5582
# Epoch 65/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.3078 - mae: 0.4173 - val_loss: 0.6876 - val_mae: 0.5512
# Epoch 66/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.2866 - mae: 0.4180 - val_loss: 0.6587 - val_mae: 0.5451
# Epoch 67/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.2800 - mae: 0.4086 - val_loss: 0.6865 - val_mae: 0.5524
# Epoch 68/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.2666 - mae: 0.4033 - val_loss: 0.6995 - val_mae: 0.5641
# Epoch 69/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.2947 - mae: 0.4296 - val_loss: 0.6893 - val_mae: 0.5494
# Epoch 70/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.2625 - mae: 0.4041 - val_loss: 0.6967 - val_mae: 0.5613
# Epoch 71/100
# 11/11 [==============================] - 1s 63ms/step - loss: 0.2822 - mae: 0.4077 - val_loss: 0.6851 - val_mae: 0.5535
# Epoch 72/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.2909 - mae: 0.4257 - val_loss: 0.6959 - val_mae: 0.5553
# Epoch 73/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.2706 - mae: 0.3895 - val_loss: 0.7047 - val_mae: 0.5542
# Epoch 74/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.3010 - mae: 0.4262 - val_loss: 0.6917 - val_mae: 0.5605
# Epoch 75/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.2696 - mae: 0.4102 - val_loss: 0.6702 - val_mae: 0.5493
# Epoch 76/100
# 11/11 [==============================] - 1s 46ms/step - loss: 0.2712 - mae: 0.4103 - val_loss: 0.6817 - val_mae: 0.5524
# Epoch 77/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.2719 - mae: 0.4051 - val_loss: 0.6919 - val_mae: 0.5563
# Epoch 78/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2852 - mae: 0.4124 - val_loss: 0.6785 - val_mae: 0.5515
# Epoch 79/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.2628 - mae: 0.4012 - val_loss: 0.6768 - val_mae: 0.5467
# Epoch 80/100
# 11/11 [==============================] - 1s 53ms/step - loss: 0.2522 - mae: 0.3918 - val_loss: 0.6928 - val_mae: 0.5566
# Epoch 81/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2730 - mae: 0.4124 - val_loss: 0.6737 - val_mae: 0.5548
# Epoch 82/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.2579 - mae: 0.3910 - val_loss: 0.6578 - val_mae: 0.5420
# Epoch 83/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.2590 - mae: 0.3956 - val_loss: 0.6787 - val_mae: 0.5487
# Epoch 84/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2752 - mae: 0.4124 - val_loss: 0.6771 - val_mae: 0.5481
# Epoch 85/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.2678 - mae: 0.4018 - val_loss: 0.6842 - val_mae: 0.5506
# Epoch 86/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.2540 - mae: 0.4015 - val_loss: 0.6833 - val_mae: 0.5550
# Epoch 87/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2901 - mae: 0.4172 - val_loss: 0.6888 - val_mae: 0.5569
# Epoch 88/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.2555 - mae: 0.3984 - val_loss: 0.6872 - val_mae: 0.5521
# Epoch 89/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.2582 - mae: 0.3967 - val_loss: 0.6856 - val_mae: 0.5500
# Epoch 90/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.2603 - mae: 0.3880 - val_loss: 0.6780 - val_mae: 0.5496
# Epoch 91/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2435 - mae: 0.3801 - val_loss: 0.7054 - val_mae: 0.5628
# Epoch 92/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2685 - mae: 0.4091 - val_loss: 0.6780 - val_mae: 0.5552
# Epoch 93/100
# 11/11 [==============================] - 1s 54ms/step - loss: 0.2357 - mae: 0.3837 - val_loss: 0.6463 - val_mae: 0.5421
# Epoch 94/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.2590 - mae: 0.3958 - val_loss: 0.7034 - val_mae: 0.5565
# Epoch 95/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.2505 - mae: 0.3903 - val_loss: 0.6736 - val_mae: 0.5525
# Epoch 96/100
# 11/11 [==============================] - 1s 52ms/step - loss: 0.2666 - mae: 0.3890 - val_loss: 0.7536 - val_mae: 0.5944
# Epoch 97/100
# 11/11 [==============================] - 1s 50ms/step - loss: 0.2565 - mae: 0.3978 - val_loss: 0.6909 - val_mae: 0.5560
# Epoch 98/100
# 11/11 [==============================] - 1s 48ms/step - loss: 0.2562 - mae: 0.3903 - val_loss: 0.6603 - val_mae: 0.5463
# Epoch 99/100
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2607 - mae: 0.3944 - val_loss: 0.6669 - val_mae: 0.5508
# Epoch 100/100
# 11/11 [==============================] - 1s 51ms/step - loss: 0.2493 - mae: 0.3889 - val_loss: 0.6985 - val_mae: 0.5654
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2202 - mae: 0.7490
# Test MAE: 0.75
