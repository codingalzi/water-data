# %% [markdown]
# **필수 라이브러리**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# **matplotlib 한글 설정**
#
# - 운영체제에 따른 한글 지원 설정. 윈도우, 우분투, 구글 코랩 지원.
# - 참고: [matplotlib에서 한글 지원하기](https://github.com/codingalzi/datapy/blob/master/matplotlib-korean.md)

# %%
import platform

if platform.system() == 'Windows': # 윈도우
    from matplotlib import font_manager, rc
    font_path = "C:/Windows/Fonts/NGULIM.TTF"
    font = font_manager.FontProperties(fname=font_path).get_name()
    rc('font', family=font)
elif platform.system() == 'Linux': # 우분투 또는 구글 코랩
    # !sudo apt-get install -y fonts-nanum*
    # !fc-cache -fv
    
    applyfont = "NanumBarunGothic"
    import matplotlib.font_manager as fm
    if not any(map(lambda ft: ft.name == applyfont, fm.fontManager.ttflist)):
        fm.fontManager.addfont("/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf")
    plt.rc("font", family=applyfont)
    plt.rc("axes", unicode_minus=False)

# %% [markdown]
# **데이터**
#
# 데이터는 연도별로 분리되어 있으며 원본 엑셀 파일은 아래 서버에 저장되어 있다.

# %%
base_url = "https://github.com/codingalzi/water-data/raw/master/reservoirs/"

# %% [markdown]
# **승촌보 (엑셀) 자료를 데이터프레임으로 불러오기**
#
# - `skiprows=0`: 0번 행 무시. 모든 워크시트 대상.
# - `header=1`: 1번 행을 header로 지정, 즉 열 인덱스로 사용.
# - `sheet_name=None`: 모든 워크시트 가져오기. 워크시트별로 하나의 df 생성. 반환값은 사전.
# - `na_values='ND'`: ND(No Data/Not Determinded) 또한 결측치로 처리. 용존산소 열에 포함되어 있음.
# - `index_col=0`: 측정일을 행 인덱스로 사용
# - `parse_dates=True`: 행 인덱스로 사용되는 날짜 대상 파싱 실행

# %% [markdown]
# 주의: 아래 모듈을 먼저 설치해야 할 수도 있다.
#
# ```python
# !pip install openpyxl
# ```

# %%
scb_yearly = pd.read_excel(base_url+"Seungchonbo.xlsx", 
                            skiprows=0, 
                            header=1, 
                            sheet_name=None,
                            na_values='ND',
                            index_col=0, 
                            parse_dates=True)

# %% [markdown]
# **승촌보 수량 데이터 불러오기**
#
# - 0번 행 무시하지 않음

# %%
scb_yearly_flow_rate = pd.read_excel(base_url+"Seungchonbo-flow_rate.xlsx", 
                            header=0, 
                            sheet_name=None,
                            na_values='ND',
                            index_col=0, 
                            parse_dates=True)

# %% [markdown]
# **승촌보(광산) 데이터 불러오기**
#
# - 0번 행 무시하지 않음
# - 행 인덱스: 1번 열
# - 한 장의 sheet 로 구성됨

# %%
scb_gs = pd.read_excel(base_url+"Seunchonbo-Gwangsan.xlsx", 
                            header=0, 
                            na_values='ND',
                            index_col=1, 
                            parse_dates=True)

# %%
scb_gs = scb_gs.iloc[:, 2:].copy()

# %%
scb_gs
# Out:
#             수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  클로로필 a(㎎/㎥)  TN(㎎/L)  TP(㎎/L)  \
# 년/월/일
# 2021-01-04    5.9     12.7       5.8       8.5         66.9    9.644    0.272
# 2021-01-14    5.3     13.5       4.7       8.6         47.4   10.516    0.120
# 2021-01-19    5.2     12.4       3.9       7.7         49.4   10.447    0.218
# 2021-01-25    8.7      9.0       4.6       8.4         51.4    8.090    0.305
# 2021-02-01    7.7     12.1       4.8       8.7         63.5    9.422    0.150
# ...           ...      ...       ...       ...          ...      ...      ...
# 2006-08-10   28.8      5.7       4.8       6.8          0.4   12.864    0.301
# 2006-09-14   22.0      7.6       6.2       4.0          0.3    6.972    0.249
# 2006-10-13   20.0      8.4       4.0       4.0          0.3   12.734    0.488
# 2006-11-09   18.0      8.2       5.9       6.6          2.0   13.626    0.892
# 2006-12-12   10.3     10.4       5.4       7.6          1.0   14.471    0.644
#
#             TOC(㎎/L)  수소이온농도  페놀류(㎎/L)  전기전도도(μS/㎝)  총대장균군수(총대장균군수/100ml)  \
# 년/월/일
# 2021-01-04       7.2     7.0         0          631                  3400
# 2021-01-14       5.1     7.4         0          508                  4800
# 2021-01-19       4.0     7.2         0          478                  3400
# 2021-01-25       5.6     7.1         0          500                 21000
# 2021-02-01       5.3     7.2         0          484                  5600
# ...              ...     ...       ...          ...                   ...
# 2006-08-10       NaN     7.9         0          226                 19700
# 2006-09-14       NaN     7.9         0          220                 29000
# 2006-10-13       NaN     8.2         0          185                 29000
# 2006-11-09       NaN     7.5         0          390                   500
# 2006-12-12       NaN     7.6         0          365                  2000
#
#             용존총질소(㎎/L)  암모니아성 질소(㎎/L)  질산성 질소(㎎/L)  용존총인(㎎/L)  인산염인(㎎/L)  \
# 년/월/일
# 2021-01-04       9.393          5.148        3.405      0.097      0.074
# 2021-01-14      10.511          6.200        3.350      0.027      0.007
# 2021-01-19       9.364          6.558        2.790      0.065      0.063
# 2021-01-25       8.066          5.866        2.183      0.215      0.162
# 2021-02-01       8.830          5.695        3.112      0.032      0.009
# ...                ...            ...          ...        ...        ...
# 2006-08-10      10.260          0.018        0.035      0.251      0.197
# 2006-09-14       5.916          0.013        5.286      0.211      0.208
# 2006-10-13      11.892          0.355        8.363      0.457      0.420
# 2006-11-09      13.553          0.014        9.374      0.595      0.430
# 2006-12-12      13.330          1.109        9.039      0.551      0.505
#
#             SS(㎎/L)  분원성대장균군수  유량(㎥/s)
# 년/월/일
# 2021-01-04     10.7       820   10.306
# 2021-01-14     10.9       190   13.200
# 2021-01-19      8.3       660   12.458
# 2021-01-25      9.7      1200   12.248
# 2021-02-01     12.5       800   31.740
# ...             ...       ...      ...
# 2006-08-10     13.2      3000      NaN
# 2006-09-14      9.2      5400      NaN
# 2006-10-13      9.2      5400      NaN
# 2006-11-09      0.4      1600      NaN
# 2006-12-12     11.2      2600      NaN
#
# [775 rows x 20 columns]

# %% [markdown]
# 날짜순으로 정렬

# %%
scb_gs.sort_index(inplace=True)

# %%
scb_gs
# Out:
#             수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  클로로필 a(㎎/㎥)  TN(㎎/L)  TP(㎎/L)  \
# 년/월/일
# 2005-12-28    4.2     12.6       6.9       4.0          4.2   14.244    0.856
# 2006-01-25    6.9     13.5       7.4       4.1         17.3   15.108    0.558
# 2006-02-24    8.3     11.0       5.9       2.8          2.0   11.880    0.473
# 2006-03-24   13.6      5.8       9.2       5.7         18.3   14.880    1.002
# 2006-04-28   16.8      9.5      11.7       6.0         17.7   12.070    1.850
# ...           ...      ...       ...       ...          ...      ...      ...
# 2021-11-22   13.3      9.4       4.1       8.3         52.2    4.738    0.097
# 2021-11-29   11.6      8.2       4.0       8.0         28.7    6.322    0.206
# 2021-12-06    9.3     10.4       4.9       7.1         42.5    5.166    0.191
# 2021-12-13   10.4     10.7       5.5       8.9         58.3    6.337    0.158
# 2021-12-20    7.4     12.0       5.8       7.8         36.6    7.282    0.125
#
#             TOC(㎎/L)  수소이온농도  페놀류(㎎/L)  전기전도도(μS/㎝)  총대장균군수(총대장균군수/100ml)  \
# 년/월/일
# 2005-12-28       NaN     6.9         0          884                   300
# 2006-01-25       NaN     7.6         0            3                   280
# 2006-02-24       NaN     7.2         0          223                   280
# 2006-03-24       NaN     8.1         0          417                   180
# 2006-04-28       NaN     8.1         0          539                   150
# ...              ...     ...       ...          ...                   ...
# 2021-11-22       5.1     6.9         0          384                  2500
# 2021-11-29       5.7     6.9         0          430                  1100
# 2021-12-06       5.3     7.0         0          413                  6600
# 2021-12-13       6.0     7.1         0          448                  4600
# 2021-12-20       6.1     7.2         0          457                  2800
#
#             용존총질소(㎎/L)  암모니아성 질소(㎎/L)  질산성 질소(㎎/L)  용존총인(㎎/L)  인산염인(㎎/L)  \
# 년/월/일
# 2005-12-28      12.672          0.035       11.530      0.670      0.658
# 2006-01-25      11.304          0.065        5.338      0.496      0.492
# 2006-02-24      11.340          0.070        7.301      0.412      0.389
# 2006-03-24      12.950          0.024       11.574      0.916      0.684
# 2006-04-28      10.699          0.033       11.397      1.727      1.054
# ...                ...            ...          ...        ...        ...
# 2021-11-22       4.519          1.253        2.526      0.042      0.033
# 2021-11-29       6.155          2.643        2.473      0.157      0.149
# 2021-12-06       4.905          1.826        2.495      0.089      0.086
# 2021-12-13       5.972          2.735        2.446      0.043      0.027
# 2021-12-20       6.960          3.172        3.023      0.034      0.018
#
#             SS(㎎/L)  분원성대장균군수  유량(㎥/s)
# 년/월/일
# 2005-12-28     16.0       100      NaN
# 2006-01-25     24.8       700      NaN
# 2006-02-24     16.8       700      NaN
# 2006-03-24      9.2       100      NaN
# 2006-04-28     34.4         9      NaN
# ...             ...       ...      ...
# 2021-11-22      6.3       570    8.454
# 2021-11-29      6.4       120    7.830
# 2021-12-06      8.8       640   13.455
# 2021-12-13     19.1       510   10.901
# 2021-12-20      8.6       410   12.991
#
# [775 rows x 20 columns]

# %%
scb_gs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 775 entries, 2005-12-28 to 2021-12-20
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   수온(℃)                 775 non-null    float64
#  1   DO(㎎/L)               775 non-null    float64
#  2   BOD(㎎/L)              775 non-null    float64
#  3   COD(㎎/L)              775 non-null    float64
#  4   클로로필 a(㎎/㎥)           775 non-null    float64
#  5   TN(㎎/L)               775 non-null    float64
#  6   TP(㎎/L)               775 non-null    float64
#  7   TOC(㎎/L)              695 non-null    float64
#  8   수소이온농도                775 non-null    float64
#  9   페놀류(㎎/L)              775 non-null    int64
#  10  전기전도도(μS/㎝)           775 non-null    int64
#  11  총대장균군수(총대장균군수/100ml)  775 non-null    int64
#  12  용존총질소(㎎/L)            775 non-null    float64
#  13  암모니아성 질소(㎎/L)         775 non-null    float64
#  14  질산성 질소(㎎/L)           775 non-null    float64
#  15  용존총인(㎎/L)             775 non-null    float64
#  16  인산염인(㎎/L)             775 non-null    float64
#  17  SS(㎎/L)               775 non-null    float64
#  18  분원성대장균군수              775 non-null    int64
#  19  유량(㎥/s)               542 non-null    float64
# dtypes: float64(16), int64(4)
# memory usage: 127.1 KB

# %%
scb_gs_w_na = scb_gs[scb_gs.isna().any(axis=1)]

# %%
scb_gs_w_na
# Out:
#             수온(℃)  DO(㎎/L)  BOD(㎎/L)  COD(㎎/L)  클로로필 a(㎎/㎥)  TN(㎎/L)  TP(㎎/L)  \
# 년/월/일
# 2005-12-28    4.2     12.6       6.9       4.0          4.2   14.244    0.856
# 2006-01-25    6.9     13.5       7.4       4.1         17.3   15.108    0.558
# 2006-02-24    8.3     11.0       5.9       2.8          2.0   11.880    0.473
# 2006-03-24   13.6      5.8       9.2       5.7         18.3   14.880    1.002
# 2006-04-28   16.8      9.5      11.7       6.0         17.7   12.070    1.850
# ...           ...      ...       ...       ...          ...      ...      ...
# 2011-12-05    8.1     13.4       1.8       5.2          4.0    4.867    0.408
# 2011-12-14    8.3     13.8       3.3       6.2         15.4    6.262    0.424
# 2011-12-21    7.1     11.8       3.1       6.4         12.1    7.850    0.660
# 2019-09-03   24.3      7.7       3.8       6.4         40.7    3.690    0.078
# 2020-02-18    7.7     10.2       6.8      12.9         45.3    6.728    0.270
#
#             TOC(㎎/L)  수소이온농도  페놀류(㎎/L)  전기전도도(μS/㎝)  총대장균군수(총대장균군수/100ml)  \
# 년/월/일
# 2005-12-28       NaN     6.9         0          884                   300
# 2006-01-25       NaN     7.6         0            3                   280
# 2006-02-24       NaN     7.2         0          223                   280
# 2006-03-24       NaN     8.1         0          417                   180
# 2006-04-28       NaN     8.1         0          539                   150
# ...              ...     ...       ...          ...                   ...
# 2011-12-05       3.8     7.4         0          428                  4400
# 2011-12-14       4.7     7.1         0          474                  4500
# 2011-12-21       5.3     6.5         0          468                  7800
# 2019-09-03       4.9     7.3         0          280                  7900
# 2020-02-18       7.4     7.4         0          365                100000
#
#             용존총질소(㎎/L)  암모니아성 질소(㎎/L)  질산성 질소(㎎/L)  용존총인(㎎/L)  인산염인(㎎/L)  \
# 년/월/일
# 2005-12-28      12.672          0.035       11.530      0.670      0.658
# 2006-01-25      11.304          0.065        5.338      0.496      0.492
# 2006-02-24      11.340          0.070        7.301      0.412      0.389
# 2006-03-24      12.950          0.024       11.574      0.916      0.684
# 2006-04-28      10.699          0.033       11.397      1.727      1.054
# ...                ...            ...          ...        ...        ...
# 2011-12-05       4.702          0.534        3.289      0.363      0.360
# 2011-12-14       6.094          1.106        3.891      0.396      0.387
# 2011-12-21       7.769          1.932        4.258      0.593      0.530
# 2019-09-03       3.456          1.444        1.526      0.036      0.035
# 2020-02-18       6.250          3.502        2.273      0.147      0.110
#
#             SS(㎎/L)  분원성대장균군수  유량(㎥/s)
# 년/월/일
# 2005-12-28     16.0       100      NaN
# 2006-01-25     24.8       700      NaN
# 2006-02-24     16.8       700      NaN
# 2006-03-24      9.2       100      NaN
# 2006-04-28     34.4         9      NaN
# ...             ...       ...      ...
# 2011-12-05      4.9      1600      NaN
# 2011-12-14      6.1       323      NaN
# 2011-12-21      5.6      2300      NaN
# 2019-09-03      8.7      5700      NaN
# 2020-02-18     15.2     12000      NaN
#
# [233 rows x 20 columns]

# %%
scb_gs_w_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 233 entries, 2005-12-28 to 2020-02-18
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   수온(℃)                 233 non-null    float64
#  1   DO(㎎/L)               233 non-null    float64
#  2   BOD(㎎/L)              233 non-null    float64
#  3   COD(㎎/L)              233 non-null    float64
#  4   클로로필 a(㎎/㎥)           233 non-null    float64
#  5   TN(㎎/L)               233 non-null    float64
#  6   TP(㎎/L)               233 non-null    float64
#  7   TOC(㎎/L)              153 non-null    float64
#  8   수소이온농도                233 non-null    float64
#  9   페놀류(㎎/L)              233 non-null    int64
#  10  전기전도도(μS/㎝)           233 non-null    int64
#  11  총대장균군수(총대장균군수/100ml)  233 non-null    int64
#  12  용존총질소(㎎/L)            233 non-null    float64
#  13  암모니아성 질소(㎎/L)         233 non-null    float64
#  14  질산성 질소(㎎/L)           233 non-null    float64
#  15  용존총인(㎎/L)             233 non-null    float64
#  16  인산염인(㎎/L)             233 non-null    float64
#  17  SS(㎎/L)               233 non-null    float64
#  18  분원성대장균군수              233 non-null    int64
#  19  유량(㎥/s)               0 non-null      float64
# dtypes: float64(16), int64(4)
# memory usage: 38.2 KB
