# %% [markdown]
# 필요한 모듈 임포트

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
import platform
plt.rc('figure', figsize=(10, 6))  # 그림 크기 설정
if platform.system() == 'Windows': # 윈도우
    from matplotlib import font_manager, rc
    font_path = "C:/Windows/Fonts/NGULIM.TTF"
    font = font_manager.FontProperties(fname=font_path).get_name()
    rc('font', family=font)
elif platform.system() == 'Linux': # 우분투 또는 구글 코랩
    # !sudo apt-get install -y fonts-nanum*
    # !fc-cache -fv
    
    applyfont = "NanumBarunGothic"
    import matplotlib.font_manager as fm
    if not any(map(lambda ft: ft.name == applyfont, fm.fontManager.ttflist)):
        fm.fontManager.addfont("/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf")
    plt.rc("font", family=applyfont)
    plt.rc("axes", unicode_minus=False)

# %%
# GradientBoosting
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# 데이터 가져오기

# %%
base_path = "https://github.com/codingalzi/water-data/raw/master/reservoirs/"
# base_path = r"C:\Users\owner\Desktop\water-source\data"

# %%
scb_yearly = pd.read_excel(base_path+"Seungchonbo.xlsx", 
# scb_yearly = pd.read_excel(base_path+"\Seungchonbo.xlsx", 
                            skiprows=0, 
                            header=1, 
                            sheet_name=None,
                            na_values='ND',
                            parse_dates=True)  # index_col = 0을 제외함

# %%
print(type(scb_yearly))  # type-dict
print(scb_yearly.keys())  # 2012년부터 2022년까지
# Out:
# <class 'dict'>
# dict_keys(['2012년', '2013년', '2014년', '2015년', '2016년', '2017년', '2018년', '2019년', '2020년', '2021년', '2022년'])

# %%
scb_yearly['2012년'].columns
# Out:
# Index(['측정일/월', '측정소명', '수온 ℃', '수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L',
#        '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L', '클로로필-a mg/㎥'],
#       dtype='object')

# %% [markdown]
# 2013년 자료부터

# %%
scb_yearly_df13 = pd.DataFrame()

for item in list(scb_yearly.keys())[1:]:
    scb_yearly_df13 = pd.concat([scb_yearly_df13, scb_yearly[item]])

# %%
scb_yearly_df13 = scb_yearly_df13.reset_index(drop=True)

# %% [markdown]
# 결측치 확인

# %%
scb_yearly_df13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82257 entries, 0 to 82256
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   측정일/월        82257 non-null  object
#  1   측정소명         82257 non-null  object
#  2   수온 ℃         64574 non-null  float64
#  3   수소이온농도       64561 non-null  float64
#  4   전기전도도 μS/cm  64524 non-null  float64
#  5   용존산소 mg/L    62656 non-null  float64
#  6   총유기탄소 mg/L   58675 non-null  float64
#  7   총질소 mg/L     59981 non-null  float64
#  8   총인 mg/L      58997 non-null  float64
#  9   클로로필-a mg/㎥  62876 non-null  float64
# dtypes: float64(8), object(2)
# memory usage: 6.3+ MB

# %%
scb_yearly_df13.isnull().sum()
# Out:
# 측정일/월              0
# 측정소명               0
# 수온 ℃           17683
# 수소이온농도         17696
# 전기전도도 μS/cm    17733
# 용존산소 mg/L      19601
# 총유기탄소 mg/L     23582
# 총질소 mg/L       22276
# 총인 mg/L        23260
# 클로로필-a mg/㎥    19381
# dtype: int64

# %%
scb_yearly_df13.head()
# Out:
#             측정일/월 측정소명  수온 ℃  수소이온농도  전기전도도 μS/cm  용존산소 mg/L  총유기탄소 mg/L  \
# 0  2013-01-01 00h   용봉   3.9     6.9        374.0       11.4         2.5
# 1  2013-01-01 01h   용봉   3.9     6.9        375.0       11.4         2.5
# 2  2013-01-01 02h   용봉   4.0     6.9        374.0       11.4         2.5
# 3  2013-01-01 03h   용봉   4.1     6.9        375.0       11.4         2.5
# 4  2013-01-01 04h   용봉   4.0     6.9        380.0       11.3         2.6
#
#    총질소 mg/L  총인 mg/L  클로로필-a mg/㎥
# 0       NaN      NaN          7.2
# 1       NaN      NaN          6.9
# 2       NaN      NaN          6.8
# 3       NaN      NaN          6.9
# 4       NaN      NaN          6.9

# %% [markdown]
# 유량 데이터 추가하기

# %%
scb_flow_yearly = pd.read_excel(base_path+"Seungchonbo_flow.xlsx", 
# scb_flow_yearly = pd.read_excel(base_path+"\Seungchonbo_flow.xlsx", 
                            header=0, 
                            sheet_name=None,
                            na_values='ND',
                            parse_dates=True)  # index_col = 0을 제외함

# %%
for year in list(scb_flow_yearly.keys())[1:]:
    scb_flow_yearly[year]['연월일시'] = scb_flow_yearly[year]['시간'].apply(lambda x : x[:-3])

# %%
scb_flow_yearly_hour = {}

for year in list(scb_flow_yearly.keys())[1:]:
    scb_flow_yearly_hour[year] = scb_flow_yearly[year].groupby('연월일시').mean()

# %%
for year in scb_flow_yearly_hour:
    scb_flow_yearly_hour[year] = scb_flow_yearly_hour[year].reset_index()

# %%
scb_flow_yearly_hour_df = pd.DataFrame()

for year in scb_flow_yearly_hour:
    scb_flow_yearly_hour_df = pd.concat([scb_flow_yearly_hour_df, scb_flow_yearly_hour[year]])

# %%
scb_flow_yearly_hour_df = scb_flow_yearly_hour_df.reset_index(drop=True)

# %%
print(scb_flow_yearly_hour_df.__len__())
print(scb_yearly_df13.__len__())
# Out:
# 84393
# 82257

# %%
scb_yearly_df13['연월일시'] = scb_yearly_df13['측정일/월'].transform(lambda x: x.strip('h').replace('-', '.'))

# %%
scb_data = pd.merge(scb_yearly_df13, scb_flow_yearly_hour_df, how='outer')

# %%
scb_data = scb_data[:82257]

# %%
scb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82257 entries, 0 to 82256
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   측정일/월        82257 non-null  object
#  1   측정소명         82257 non-null  object
#  2   수온 ℃         64574 non-null  float64
#  3   수소이온농도       64561 non-null  float64
#  4   전기전도도 μS/cm  64524 non-null  float64
#  5   용존산소 mg/L    62656 non-null  float64
#  6   총유기탄소 mg/L   58675 non-null  float64
#  7   총질소 mg/L     59981 non-null  float64
#  8   총인 mg/L      58997 non-null  float64
#  9   클로로필-a mg/㎥  62876 non-null  float64
#  10  연월일시         82257 non-null  object
#  11   상류수위(EL.m)  82231 non-null  float64
#  12   하류수위(EL.m)  82231 non-null  float64
#  13   유입량(㎥/s)    82231 non-null  float64
#  14   방류량(㎥/s)    82231 non-null  float64
# dtypes: float64(12), object(3)
# memory usage: 10.0+ MB

# %%
scb_data.columns = [x.strip() for x in list(scb_data.columns)]

# %%
scb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82257 entries, 0 to 82256
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   측정일/월        82257 non-null  object
#  1   측정소명         82257 non-null  object
#  2   수온 ℃         64574 non-null  float64
#  3   수소이온농도       64561 non-null  float64
#  4   전기전도도 μS/cm  64524 non-null  float64
#  5   용존산소 mg/L    62656 non-null  float64
#  6   총유기탄소 mg/L   58675 non-null  float64
#  7   총질소 mg/L     59981 non-null  float64
#  8   총인 mg/L      58997 non-null  float64
#  9   클로로필-a mg/㎥  62876 non-null  float64
#  10  연월일시         82257 non-null  object
#  11  상류수위(EL.m)   82231 non-null  float64
#  12  하류수위(EL.m)   82231 non-null  float64
#  13  유입량(㎥/s)     82231 non-null  float64
#  14  방류량(㎥/s)     82231 non-null  float64
# dtypes: float64(12), object(3)
# memory usage: 10.0+ MB

# %%
scb_data = scb_data.loc[:, list(scb_data.columns)[:-5] + list(scb_data.columns)[-4:-3] + list(scb_data.columns)[-1:]]

# %%
scb_data.columns
# Out:
# Index(['측정일/월', '측정소명', '수온 ℃', '수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L',
#        '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L', '클로로필-a mg/㎥', '상류수위(EL.m)',
#        '방류량(㎥/s)'],
#       dtype='object')

# %%
scb_data.isnull().sum()
# Out:
# 측정일/월              0
# 측정소명               0
# 수온 ℃           17683
# 수소이온농도         17696
# 전기전도도 μS/cm    17733
# 용존산소 mg/L      19601
# 총유기탄소 mg/L     23582
# 총질소 mg/L       22276
# 총인 mg/L        23260
# 클로로필-a mg/㎥    19381
# 상류수위(EL.m)        26
# 방류량(㎥/s)          26
# dtype: int64

# %%
scb_data.isnull().sum() /len(scb_data)
# Out:
# 측정일/월          0.000000
# 측정소명           0.000000
# 수온 ℃           0.214973
# 수소이온농도         0.215131
# 전기전도도 μS/cm    0.215580
# 용존산소 mg/L      0.238290
# 총유기탄소 mg/L     0.286687
# 총질소 mg/L       0.270810
# 총인 mg/L        0.282772
# 클로로필-a mg/㎥    0.235615
# 상류수위(EL.m)     0.000316
# 방류량(㎥/s)       0.000316
# dtype: float64

# %%
len(scb_data)
# Out:
# 82257

# %% [markdown]
# 시간데이터 추가

# %%
scb_df = scb_data.copy()

# %%
scb_df.columns
# Out:
# Index(['측정일/월', '측정소명', '수온 ℃', '수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L',
#        '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L', '클로로필-a mg/㎥', '상류수위(EL.m)',
#        '방류량(㎥/s)'],
#       dtype='object')

# %%
col_c = list(scb_df.columns.copy())
col_c.remove('클로로필-a mg/㎥')

# %%
col_c
# Out:
# ['측정일/월',
#  '측정소명',
#  '수온 ℃',
#  '수소이온농도',
#  '전기전도도 μS/cm',
#  '용존산소 mg/L',
#  '총유기탄소 mg/L',
#  '총질소 mg/L',
#  '총인 mg/L',
#  '상류수위(EL.m)',
#  '방류량(㎥/s)']

# %%
for var in col_c[2:]:
    for i in range(1, 73):
        scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# Out:
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# ...
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_31476\928123686.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   scb_df[str(i) + 'shift' + var] = scb_df[var].shift(i)

# %%
len(scb_df)
# Out:
# 82257

# %%
scb_df.columns
# Out:
# Index(['측정일/월', '측정소명', '수온 ℃', '수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L',
#        '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L', '클로로필-a mg/㎥',
#        ...
#        '63shift방류량(㎥/s)', '64shift방류량(㎥/s)', '65shift방류량(㎥/s)',
#        '66shift방류량(㎥/s)', '67shift방류량(㎥/s)', '68shift방류량(㎥/s)',
#        '69shift방류량(㎥/s)', '70shift방류량(㎥/s)', '71shift방류량(㎥/s)',
#        '72shift방류량(㎥/s)'],
#       dtype='object', length=660)

# %%
len(scb_df)
# Out:
# 82257

# %% [markdown]
# 결측치 보간법

# %%
from datetime import datetime

# %%
scb_df = scb_df.copy()

# %%
scb_df['측정일/월'] = scb_df['측정일/월'].transform(lambda x: datetime.strptime(x[:-1], '%Y-%m-%d %H'))

# %%
scb_df = scb_df.copy().set_index('측정일/월').interpolate(method='time')

# %%
scb_df = scb_df.dropna()

# %%
scb_df.__len__()
# Out:
# 80082

# %%
scb_df.columns
# Out:
# Index(['측정소명', '수온 ℃', '수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L', '총유기탄소 mg/L',
#        '총질소 mg/L', '총인 mg/L', '클로로필-a mg/㎥', '상류수위(EL.m)',
#        ...
#        '63shift방류량(㎥/s)', '64shift방류량(㎥/s)', '65shift방류량(㎥/s)',
#        '66shift방류량(㎥/s)', '67shift방류량(㎥/s)', '68shift방류량(㎥/s)',
#        '69shift방류량(㎥/s)', '70shift방류량(㎥/s)', '71shift방류량(㎥/s)',
#        '72shift방류량(㎥/s)'],
#       dtype='object', length=659)

# %%
scb_df.head()
# Out:
#                     측정소명  수온 ℃  수소이온농도  전기전도도 μS/cm  용존산소 mg/L  총유기탄소 mg/L  \
# 측정일/월
# 2013-04-01 16:00:00   용봉  14.0     6.8        337.0       4.75        3.45
# 2013-04-01 17:00:00   용봉  14.0     6.8        340.0       4.90        3.50
# 2013-04-01 18:00:00   용봉  13.9     6.8        341.0       4.90        3.50
# 2013-04-01 19:00:00   용봉  13.7     6.8        345.0       4.90        3.40
# 2013-04-01 20:00:00   용봉  13.7     6.8        353.0       4.90        3.50
#
#                      총질소 mg/L  총인 mg/L  클로로필-a mg/㎥  상류수위(EL.m)  ...  \
# 측정일/월                                                            ...
# 2013-04-01 16:00:00     7.083    0.110        40.85    7.520000  ...
# 2013-04-01 17:00:00     7.077    0.109        45.80    7.528333  ...
# 2013-04-01 18:00:00     7.100    0.107        46.10    7.535000  ...
# 2013-04-01 19:00:00     7.203    0.106        47.00    7.540000  ...
# 2013-04-01 20:00:00     7.108    0.105        45.20    7.540000  ...
#
#                      63shift방류량(㎥/s)  64shift방류량(㎥/s)  65shift방류량(㎥/s)  \
# 측정일/월
# 2013-04-01 16:00:00        14.436667        14.496667        14.503333
# 2013-04-01 17:00:00        14.415000        14.436667        14.496667
# 2013-04-01 18:00:00        14.335000        14.415000        14.436667
# 2013-04-01 19:00:00        14.330000        14.335000        14.415000
# 2013-04-01 20:00:00        14.315000        14.330000        14.335000
#
#                      66shift방류량(㎥/s)  67shift방류량(㎥/s)  68shift방류량(㎥/s)  \
# 측정일/월
# 2013-04-01 16:00:00        14.551667        14.580000        14.615000
# 2013-04-01 17:00:00        14.503333        14.551667        14.580000
# 2013-04-01 18:00:00        14.496667        14.503333        14.551667
# 2013-04-01 19:00:00        14.436667        14.496667        14.503333
# 2013-04-01 20:00:00        14.415000        14.436667        14.496667
#
#                      69shift방류량(㎥/s)  70shift방류량(㎥/s)  71shift방류량(㎥/s)  \
# 측정일/월
# 2013-04-01 16:00:00        15.346667        15.973333        13.275000
# 2013-04-01 17:00:00        14.615000        15.346667        15.973333
# 2013-04-01 18:00:00        14.580000        14.615000        15.346667
# 2013-04-01 19:00:00        14.551667        14.580000        14.615000
# 2013-04-01 20:00:00        14.503333        14.551667        14.580000
#
#                      72shift방류량(㎥/s)
# 측정일/월
# 2013-04-01 16:00:00        12.343333
# 2013-04-01 17:00:00        13.275000
# 2013-04-01 18:00:00        15.973333
# 2013-04-01 19:00:00        15.346667
# 2013-04-01 20:00:00        14.615000
#
# [5 rows x 659 columns]

# %%
col = list(scb_df.columns[1:])
#print(col)

# %%
col_v = col.copy()
col_v.remove('클로로필-a mg/㎥')
#print(col_v)

# %% [markdown]
# 피처 정규화 없이

# %%
X_train, X_test, y_train, y_test = train_test_split(scb_df.loc[:, col_v], scb_df['클로로필-a mg/㎥'], random_state=42)
gb_reg = GradientBoostingRegressor(random_state=42)

parameters = {'max_depth':[10], 'learning_rate':[0.05]}
# parameters = {'max_depth':[5, 10, 15], 'learning_rate':[0.05, 0.1, 0.2]}

# %%
gb_grid = GridSearchCV(gb_reg, param_grid=parameters, cv=3, verbose=5)

# %%
gb_grid.fit(X_train, np.log1p(y_train))
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ..learning_rate=0.05, max_depth=10;, score=0.961 total time=19.3min
# [CV 2/3] END ..learning_rate=0.05, max_depth=10;, score=0.962 total time=21.7min
# [CV 3/3] END ..learning_rate=0.05, max_depth=10;, score=0.960 total time=20.0min
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(random_state=42),
#              param_grid={'learning_rate': [0.05], 'max_depth': [10]},
#              verbose=5)

# %%
scores_df = pd.DataFrame(gb_grid.cv_results_)

# %%
scores_df.sort_values(by=['rank_test_score'], inplace=True)
scores_df[['params', 'mean_test_score', 'rank_test_score']].head()
# Out:
#                                      params  mean_test_score  rank_test_score
# 0  {'learning_rate': 0.05, 'max_depth': 10}         0.960866                1

# %%
gb_grid.best_params_
# Out:
# {'learning_rate': 0.05, 'max_depth': 10}

# %%
estimator = gb_grid.best_estimator_

# %%
pred = estimator.predict(X_test)

# %%
for score, name in zip(estimator.feature_importances_, col_v):
    print(round(score, 2), name)
# Out:
# 0.02 수온 ℃
# 0.14 수소이온농도
# 0.07 전기전도도 μS/cm
# 0.05 용존산소 mg/L
# 0.01 총유기탄소 mg/L
# 0.01 총질소 mg/L
# 0.0 총인 mg/L
# 0.0 상류수위(EL.m)
# 0.01 방류량(㎥/s)
# 0.0 1shift수온 ℃
# 0.01 2shift수온 ℃
# 0.0 3shift수온 ℃
# 0.0 4shift수온 ℃
# 0.0 5shift수온 ℃
# 0.0 6shift수온 ℃
# 0.01 7shift수온 ℃
# 0.0 8shift수온 ℃
# 0.0 9shift수온 ℃
# 0.0 10shift수온 ℃
# 0.0 11shift수온 ℃
# 0.0 12shift수온 ℃
# 0.0 13shift수온 ℃
# 0.0 14shift수온 ℃
# 0.0 15shift수온 ℃
# 0.01 16shift수온 ℃
# 0.0 17shift수온 ℃
# 0.0 18shift수온 ℃
# 0.0 19shift수온 ℃
# 0.01 20shift수온 ℃
# 0.0 21shift수온 ℃
# 0.0 22shift수온 ℃
# 0.0 23shift수온 ℃
# 0.01 24shift수온 ℃
# 0.0 25shift수온 ℃
# 0.0 26shift수온 ℃
# 0.0 27shift수온 ℃
# 0.0 28shift수온 ℃
# 0.0 29shift수온 ℃
# 0.0 30shift수온 ℃
# 0.0 31shift수온 ℃
# 0.0 32shift수온 ℃
# 0.0 33shift수온 ℃
# 0.0 34shift수온 ℃
# 0.0 35shift수온 ℃
# 0.0 36shift수온 ℃
# 0.0 37shift수온 ℃
# 0.0 38shift수온 ℃
# 0.0 39shift수온 ℃
# 0.0 40shift수온 ℃
# 0.0 41shift수온 ℃
# 0.0 42shift수온 ℃
# 0.0 43shift수온 ℃
# 0.0 44shift수온 ℃
# 0.0 45shift수온 ℃
# 0.0 46shift수온 ℃
# 0.0 47shift수온 ℃
# 0.0 48shift수온 ℃
# 0.0 49shift수온 ℃
# 0.0 50shift수온 ℃
# 0.0 51shift수온 ℃
# 0.0 52shift수온 ℃
# 0.0 53shift수온 ℃
# 0.0 54shift수온 ℃
# 0.0 55shift수온 ℃
# 0.0 56shift수온 ℃
# 0.0 57shift수온 ℃
# 0.0 58shift수온 ℃
# 0.0 59shift수온 ℃
# 0.0 60shift수온 ℃
# 0.0 61shift수온 ℃
# 0.0 62shift수온 ℃
# 0.0 63shift수온 ℃
# 0.0 64shift수온 ℃
# 0.0 65shift수온 ℃
# 0.0 66shift수온 ℃
# 0.0 67shift수온 ℃
# 0.0 68shift수온 ℃
# 0.0 69shift수온 ℃
# 0.0 70shift수온 ℃
# 0.0 71shift수온 ℃
# 0.0 72shift수온 ℃
# 0.06 1shift수소이온농도
# 0.02 2shift수소이온농도
# 0.02 3shift수소이온농도
# 0.0 4shift수소이온농도
# 0.0 5shift수소이온농도
# 0.0 6shift수소이온농도
# 0.0 7shift수소이온농도
# 0.0 8shift수소이온농도
# 0.0 9shift수소이온농도
# 0.0 10shift수소이온농도
# 0.0 11shift수소이온농도
# 0.0 12shift수소이온농도
# 0.0 13shift수소이온농도
# 0.0 14shift수소이온농도
# 0.0 15shift수소이온농도
# 0.0 16shift수소이온농도
# 0.0 17shift수소이온농도
# 0.0 18shift수소이온농도
# 0.0 19shift수소이온농도
# 0.0 20shift수소이온농도
# 0.0 21shift수소이온농도
# 0.0 22shift수소이온농도
# 0.0 23shift수소이온농도
# 0.0 24shift수소이온농도
# 0.0 25shift수소이온농도
# 0.0 26shift수소이온농도
# 0.0 27shift수소이온농도
# 0.0 28shift수소이온농도
# 0.0 29shift수소이온농도
# 0.0 30shift수소이온농도
# 0.0 31shift수소이온농도
# 0.0 32shift수소이온농도
# 0.0 33shift수소이온농도
# 0.0 34shift수소이온농도
# 0.0 35shift수소이온농도
# 0.0 36shift수소이온농도
# 0.0 37shift수소이온농도
# 0.0 38shift수소이온농도
# 0.0 39shift수소이온농도
# 0.0 40shift수소이온농도
# 0.0 41shift수소이온농도
# 0.0 42shift수소이온농도
# 0.0 43shift수소이온농도
# 0.0 44shift수소이온농도
# 0.0 45shift수소이온농도
# 0.0 46shift수소이온농도
# 0.0 47shift수소이온농도
# 0.0 48shift수소이온농도
# 0.0 49shift수소이온농도
# 0.0 50shift수소이온농도
# 0.0 51shift수소이온농도
# 0.0 52shift수소이온농도
# 0.0 53shift수소이온농도
# 0.0 54shift수소이온농도
# 0.0 55shift수소이온농도
# 0.0 56shift수소이온농도
# 0.0 57shift수소이온농도
# 0.0 58shift수소이온농도
# 0.0 59shift수소이온농도
# 0.0 60shift수소이온농도
# 0.0 61shift수소이온농도
# 0.0 62shift수소이온농도
# 0.0 63shift수소이온농도
# 0.0 64shift수소이온농도
# 0.0 65shift수소이온농도
# 0.0 66shift수소이온농도
# 0.0 67shift수소이온농도
# 0.0 68shift수소이온농도
# 0.0 69shift수소이온농도
# 0.0 70shift수소이온농도
# 0.0 71shift수소이온농도
# 0.0 72shift수소이온농도
# 0.07 1shift전기전도도 μS/cm
# 0.01 2shift전기전도도 μS/cm
# 0.0 3shift전기전도도 μS/cm
# 0.0 4shift전기전도도 μS/cm
# 0.0 5shift전기전도도 μS/cm
# 0.0 6shift전기전도도 μS/cm
# 0.0 7shift전기전도도 μS/cm
# 0.0 8shift전기전도도 μS/cm
# 0.0 9shift전기전도도 μS/cm
# 0.0 10shift전기전도도 μS/cm
# 0.0 11shift전기전도도 μS/cm
# 0.0 12shift전기전도도 μS/cm
# 0.0 13shift전기전도도 μS/cm
# 0.0 14shift전기전도도 μS/cm
# 0.0 15shift전기전도도 μS/cm
# 0.0 16shift전기전도도 μS/cm
# 0.0 17shift전기전도도 μS/cm
# 0.0 18shift전기전도도 μS/cm
# 0.0 19shift전기전도도 μS/cm
# 0.0 20shift전기전도도 μS/cm
# 0.0 21shift전기전도도 μS/cm
# 0.0 22shift전기전도도 μS/cm
# 0.0 23shift전기전도도 μS/cm
# 0.0 24shift전기전도도 μS/cm
# 0.0 25shift전기전도도 μS/cm
# 0.0 26shift전기전도도 μS/cm
# 0.0 27shift전기전도도 μS/cm
# 0.0 28shift전기전도도 μS/cm
# 0.0 29shift전기전도도 μS/cm
# 0.0 30shift전기전도도 μS/cm
# 0.0 31shift전기전도도 μS/cm
# 0.0 32shift전기전도도 μS/cm
# 0.0 33shift전기전도도 μS/cm
# 0.0 34shift전기전도도 μS/cm
# 0.0 35shift전기전도도 μS/cm
# 0.0 36shift전기전도도 μS/cm
# 0.0 37shift전기전도도 μS/cm
# 0.0 38shift전기전도도 μS/cm
# 0.0 39shift전기전도도 μS/cm
# 0.0 40shift전기전도도 μS/cm
# 0.0 41shift전기전도도 μS/cm
# 0.0 42shift전기전도도 μS/cm
# 0.0 43shift전기전도도 μS/cm
# 0.0 44shift전기전도도 μS/cm
# 0.0 45shift전기전도도 μS/cm
# 0.0 46shift전기전도도 μS/cm
# 0.0 47shift전기전도도 μS/cm
# 0.0 48shift전기전도도 μS/cm
# 0.0 49shift전기전도도 μS/cm
# 0.0 50shift전기전도도 μS/cm
# 0.0 51shift전기전도도 μS/cm
# 0.0 52shift전기전도도 μS/cm
# 0.0 53shift전기전도도 μS/cm
# 0.0 54shift전기전도도 μS/cm
# 0.0 55shift전기전도도 μS/cm
# 0.0 56shift전기전도도 μS/cm
# 0.0 57shift전기전도도 μS/cm
# 0.0 58shift전기전도도 μS/cm
# 0.0 59shift전기전도도 μS/cm
# 0.0 60shift전기전도도 μS/cm
# 0.0 61shift전기전도도 μS/cm
# 0.0 62shift전기전도도 μS/cm
# 0.0 63shift전기전도도 μS/cm
# 0.0 64shift전기전도도 μS/cm
# 0.0 65shift전기전도도 μS/cm
# 0.0 66shift전기전도도 μS/cm
# 0.0 67shift전기전도도 μS/cm
# 0.0 68shift전기전도도 μS/cm
# 0.0 69shift전기전도도 μS/cm
# 0.0 70shift전기전도도 μS/cm
# 0.0 71shift전기전도도 μS/cm
# 0.0 72shift전기전도도 μS/cm
# 0.01 1shift용존산소 mg/L
# 0.0 2shift용존산소 mg/L
# 0.0 3shift용존산소 mg/L
# 0.0 4shift용존산소 mg/L
# 0.0 5shift용존산소 mg/L
# 0.0 6shift용존산소 mg/L
# 0.0 7shift용존산소 mg/L
# 0.01 8shift용존산소 mg/L
# 0.0 9shift용존산소 mg/L
# 0.0 10shift용존산소 mg/L
# 0.0 11shift용존산소 mg/L
# 0.0 12shift용존산소 mg/L
# 0.0 13shift용존산소 mg/L
# 0.0 14shift용존산소 mg/L
# 0.0 15shift용존산소 mg/L
# 0.0 16shift용존산소 mg/L
# 0.0 17shift용존산소 mg/L
# 0.0 18shift용존산소 mg/L
# 0.0 19shift용존산소 mg/L
# 0.0 20shift용존산소 mg/L
# 0.0 21shift용존산소 mg/L
# 0.0 22shift용존산소 mg/L
# 0.0 23shift용존산소 mg/L
# 0.0 24shift용존산소 mg/L
# 0.0 25shift용존산소 mg/L
# 0.0 26shift용존산소 mg/L
# 0.0 27shift용존산소 mg/L
# 0.0 28shift용존산소 mg/L
# 0.0 29shift용존산소 mg/L
# 0.0 30shift용존산소 mg/L
# 0.0 31shift용존산소 mg/L
# 0.0 32shift용존산소 mg/L
# 0.0 33shift용존산소 mg/L
# 0.0 34shift용존산소 mg/L
# 0.0 35shift용존산소 mg/L
# 0.0 36shift용존산소 mg/L
# 0.0 37shift용존산소 mg/L
# 0.0 38shift용존산소 mg/L
# 0.0 39shift용존산소 mg/L
# 0.0 40shift용존산소 mg/L
# 0.0 41shift용존산소 mg/L
# 0.0 42shift용존산소 mg/L
# 0.0 43shift용존산소 mg/L
# 0.0 44shift용존산소 mg/L
# 0.0 45shift용존산소 mg/L
# 0.0 46shift용존산소 mg/L
# 0.0 47shift용존산소 mg/L
# 0.0 48shift용존산소 mg/L
# 0.0 49shift용존산소 mg/L
# 0.0 50shift용존산소 mg/L
# 0.0 51shift용존산소 mg/L
# 0.0 52shift용존산소 mg/L
# 0.0 53shift용존산소 mg/L
# 0.0 54shift용존산소 mg/L
# 0.0 55shift용존산소 mg/L
# 0.0 56shift용존산소 mg/L
# 0.0 57shift용존산소 mg/L
# 0.0 58shift용존산소 mg/L
# 0.0 59shift용존산소 mg/L
# 0.0 60shift용존산소 mg/L
# 0.0 61shift용존산소 mg/L
# 0.0 62shift용존산소 mg/L
# 0.0 63shift용존산소 mg/L
# 0.0 64shift용존산소 mg/L
# 0.0 65shift용존산소 mg/L
# 0.0 66shift용존산소 mg/L
# 0.0 67shift용존산소 mg/L
# 0.0 68shift용존산소 mg/L
# 0.0 69shift용존산소 mg/L
# 0.0 70shift용존산소 mg/L
# 0.0 71shift용존산소 mg/L
# 0.0 72shift용존산소 mg/L
# 0.0 1shift총유기탄소 mg/L
# 0.0 2shift총유기탄소 mg/L
# 0.0 3shift총유기탄소 mg/L
# 0.0 4shift총유기탄소 mg/L
# 0.0 5shift총유기탄소 mg/L
# 0.0 6shift총유기탄소 mg/L
# 0.0 7shift총유기탄소 mg/L
# 0.0 8shift총유기탄소 mg/L
# 0.0 9shift총유기탄소 mg/L
# 0.0 10shift총유기탄소 mg/L
# 0.0 11shift총유기탄소 mg/L
# 0.0 12shift총유기탄소 mg/L
# 0.0 13shift총유기탄소 mg/L
# 0.0 14shift총유기탄소 mg/L
# 0.0 15shift총유기탄소 mg/L
# 0.0 16shift총유기탄소 mg/L
# 0.0 17shift총유기탄소 mg/L
# 0.0 18shift총유기탄소 mg/L
# 0.0 19shift총유기탄소 mg/L
# 0.0 20shift총유기탄소 mg/L
# 0.0 21shift총유기탄소 mg/L
# 0.0 22shift총유기탄소 mg/L
# 0.0 23shift총유기탄소 mg/L
# 0.0 24shift총유기탄소 mg/L
# 0.0 25shift총유기탄소 mg/L
# 0.0 26shift총유기탄소 mg/L
# 0.0 27shift총유기탄소 mg/L
# 0.0 28shift총유기탄소 mg/L
# 0.0 29shift총유기탄소 mg/L
# 0.0 30shift총유기탄소 mg/L
# 0.0 31shift총유기탄소 mg/L
# 0.0 32shift총유기탄소 mg/L
# 0.0 33shift총유기탄소 mg/L
# 0.0 34shift총유기탄소 mg/L
# 0.0 35shift총유기탄소 mg/L
# 0.0 36shift총유기탄소 mg/L
# 0.0 37shift총유기탄소 mg/L
# 0.0 38shift총유기탄소 mg/L
# 0.0 39shift총유기탄소 mg/L
# 0.0 40shift총유기탄소 mg/L
# 0.0 41shift총유기탄소 mg/L
# 0.0 42shift총유기탄소 mg/L
# 0.0 43shift총유기탄소 mg/L
# 0.0 44shift총유기탄소 mg/L
# 0.0 45shift총유기탄소 mg/L
# 0.0 46shift총유기탄소 mg/L
# 0.0 47shift총유기탄소 mg/L
# 0.0 48shift총유기탄소 mg/L
# 0.0 49shift총유기탄소 mg/L
# 0.0 50shift총유기탄소 mg/L
# 0.0 51shift총유기탄소 mg/L
# 0.0 52shift총유기탄소 mg/L
# 0.0 53shift총유기탄소 mg/L
# 0.0 54shift총유기탄소 mg/L
# 0.0 55shift총유기탄소 mg/L
# 0.0 56shift총유기탄소 mg/L
# 0.0 57shift총유기탄소 mg/L
# 0.0 58shift총유기탄소 mg/L
# 0.0 59shift총유기탄소 mg/L
# 0.0 60shift총유기탄소 mg/L
# 0.0 61shift총유기탄소 mg/L
# 0.0 62shift총유기탄소 mg/L
# 0.0 63shift총유기탄소 mg/L
# 0.0 64shift총유기탄소 mg/L
# 0.0 65shift총유기탄소 mg/L
# 0.0 66shift총유기탄소 mg/L
# 0.0 67shift총유기탄소 mg/L
# 0.0 68shift총유기탄소 mg/L
# 0.0 69shift총유기탄소 mg/L
# 0.0 70shift총유기탄소 mg/L
# 0.0 71shift총유기탄소 mg/L
# 0.0 72shift총유기탄소 mg/L
# 0.0 1shift총질소 mg/L
# 0.0 2shift총질소 mg/L
# 0.0 3shift총질소 mg/L
# 0.0 4shift총질소 mg/L
# 0.0 5shift총질소 mg/L
# 0.0 6shift총질소 mg/L
# 0.0 7shift총질소 mg/L
# 0.0 8shift총질소 mg/L
# 0.0 9shift총질소 mg/L
# 0.0 10shift총질소 mg/L
# 0.0 11shift총질소 mg/L
# 0.0 12shift총질소 mg/L
# 0.0 13shift총질소 mg/L
# 0.0 14shift총질소 mg/L
# 0.0 15shift총질소 mg/L
# 0.0 16shift총질소 mg/L
# 0.0 17shift총질소 mg/L
# 0.0 18shift총질소 mg/L
# 0.0 19shift총질소 mg/L
# 0.0 20shift총질소 mg/L
# 0.0 21shift총질소 mg/L
# 0.0 22shift총질소 mg/L
# 0.0 23shift총질소 mg/L
# 0.0 24shift총질소 mg/L
# 0.0 25shift총질소 mg/L
# 0.0 26shift총질소 mg/L
# 0.0 27shift총질소 mg/L
# 0.0 28shift총질소 mg/L
# 0.0 29shift총질소 mg/L
# 0.0 30shift총질소 mg/L
# 0.0 31shift총질소 mg/L
# 0.0 32shift총질소 mg/L
# 0.0 33shift총질소 mg/L
# 0.0 34shift총질소 mg/L
# 0.0 35shift총질소 mg/L
# 0.0 36shift총질소 mg/L
# 0.0 37shift총질소 mg/L
# 0.0 38shift총질소 mg/L
# 0.0 39shift총질소 mg/L
# 0.0 40shift총질소 mg/L
# 0.0 41shift총질소 mg/L
# 0.0 42shift총질소 mg/L
# 0.0 43shift총질소 mg/L
# 0.0 44shift총질소 mg/L
# 0.0 45shift총질소 mg/L
# 0.0 46shift총질소 mg/L
# 0.0 47shift총질소 mg/L
# 0.0 48shift총질소 mg/L
# 0.0 49shift총질소 mg/L
# 0.0 50shift총질소 mg/L
# 0.0 51shift총질소 mg/L
# 0.0 52shift총질소 mg/L
# 0.0 53shift총질소 mg/L
# 0.0 54shift총질소 mg/L
# 0.0 55shift총질소 mg/L
# 0.0 56shift총질소 mg/L
# 0.0 57shift총질소 mg/L
# 0.0 58shift총질소 mg/L
# 0.0 59shift총질소 mg/L
# 0.0 60shift총질소 mg/L
# 0.0 61shift총질소 mg/L
# 0.0 62shift총질소 mg/L
# 0.0 63shift총질소 mg/L
# 0.0 64shift총질소 mg/L
# 0.0 65shift총질소 mg/L
# 0.0 66shift총질소 mg/L
# 0.0 67shift총질소 mg/L
# 0.0 68shift총질소 mg/L
# 0.0 69shift총질소 mg/L
# 0.0 70shift총질소 mg/L
# 0.0 71shift총질소 mg/L
# 0.0 72shift총질소 mg/L
# 0.0 1shift총인 mg/L
# 0.0 2shift총인 mg/L
# 0.0 3shift총인 mg/L
# 0.0 4shift총인 mg/L
# 0.0 5shift총인 mg/L
# 0.0 6shift총인 mg/L
# 0.0 7shift총인 mg/L
# 0.0 8shift총인 mg/L
# 0.0 9shift총인 mg/L
# 0.0 10shift총인 mg/L
# 0.0 11shift총인 mg/L
# 0.0 12shift총인 mg/L
# 0.0 13shift총인 mg/L
# 0.0 14shift총인 mg/L
# 0.0 15shift총인 mg/L
# 0.0 16shift총인 mg/L
# 0.0 17shift총인 mg/L
# 0.0 18shift총인 mg/L
# 0.0 19shift총인 mg/L
# 0.0 20shift총인 mg/L
# 0.0 21shift총인 mg/L
# 0.0 22shift총인 mg/L
# 0.0 23shift총인 mg/L
# 0.0 24shift총인 mg/L
# 0.0 25shift총인 mg/L
# 0.0 26shift총인 mg/L
# 0.0 27shift총인 mg/L
# 0.0 28shift총인 mg/L
# 0.0 29shift총인 mg/L
# 0.0 30shift총인 mg/L
# 0.0 31shift총인 mg/L
# 0.0 32shift총인 mg/L
# 0.0 33shift총인 mg/L
# 0.0 34shift총인 mg/L
# 0.0 35shift총인 mg/L
# 0.0 36shift총인 mg/L
# 0.0 37shift총인 mg/L
# 0.0 38shift총인 mg/L
# 0.0 39shift총인 mg/L
# 0.0 40shift총인 mg/L
# 0.0 41shift총인 mg/L
# 0.0 42shift총인 mg/L
# 0.0 43shift총인 mg/L
# 0.0 44shift총인 mg/L
# 0.0 45shift총인 mg/L
# 0.0 46shift총인 mg/L
# 0.0 47shift총인 mg/L
# 0.0 48shift총인 mg/L
# 0.0 49shift총인 mg/L
# 0.0 50shift총인 mg/L
# 0.0 51shift총인 mg/L
# 0.0 52shift총인 mg/L
# 0.0 53shift총인 mg/L
# 0.0 54shift총인 mg/L
# 0.0 55shift총인 mg/L
# 0.0 56shift총인 mg/L
# 0.0 57shift총인 mg/L
# 0.0 58shift총인 mg/L
# 0.0 59shift총인 mg/L
# 0.0 60shift총인 mg/L
# 0.0 61shift총인 mg/L
# 0.0 62shift총인 mg/L
# 0.0 63shift총인 mg/L
# 0.0 64shift총인 mg/L
# 0.0 65shift총인 mg/L
# 0.0 66shift총인 mg/L
# 0.0 67shift총인 mg/L
# 0.0 68shift총인 mg/L
# 0.0 69shift총인 mg/L
# 0.0 70shift총인 mg/L
# 0.0 71shift총인 mg/L
# 0.0 72shift총인 mg/L
# 0.0 1shift상류수위(EL.m)
# 0.0 2shift상류수위(EL.m)
# 0.0 3shift상류수위(EL.m)
# 0.0 4shift상류수위(EL.m)
# 0.0 5shift상류수위(EL.m)
# 0.0 6shift상류수위(EL.m)
# 0.0 7shift상류수위(EL.m)
# 0.0 8shift상류수위(EL.m)
# 0.0 9shift상류수위(EL.m)
# 0.0 10shift상류수위(EL.m)
# 0.0 11shift상류수위(EL.m)
# 0.0 12shift상류수위(EL.m)
# 0.0 13shift상류수위(EL.m)
# 0.0 14shift상류수위(EL.m)
# 0.0 15shift상류수위(EL.m)
# 0.0 16shift상류수위(EL.m)
# 0.0 17shift상류수위(EL.m)
# 0.0 18shift상류수위(EL.m)
# 0.0 19shift상류수위(EL.m)
# 0.0 20shift상류수위(EL.m)
# 0.0 21shift상류수위(EL.m)
# 0.0 22shift상류수위(EL.m)
# 0.0 23shift상류수위(EL.m)
# 0.0 24shift상류수위(EL.m)
# 0.0 25shift상류수위(EL.m)
# 0.0 26shift상류수위(EL.m)
# 0.0 27shift상류수위(EL.m)
# 0.0 28shift상류수위(EL.m)
# 0.0 29shift상류수위(EL.m)
# 0.0 30shift상류수위(EL.m)
# 0.0 31shift상류수위(EL.m)
# 0.0 32shift상류수위(EL.m)
# 0.0 33shift상류수위(EL.m)
# 0.0 34shift상류수위(EL.m)
# 0.0 35shift상류수위(EL.m)
# 0.0 36shift상류수위(EL.m)
# 0.0 37shift상류수위(EL.m)
# 0.0 38shift상류수위(EL.m)
# 0.0 39shift상류수위(EL.m)
# 0.0 40shift상류수위(EL.m)
# 0.0 41shift상류수위(EL.m)
# 0.0 42shift상류수위(EL.m)
# 0.0 43shift상류수위(EL.m)
# 0.0 44shift상류수위(EL.m)
# 0.0 45shift상류수위(EL.m)
# 0.0 46shift상류수위(EL.m)
# 0.0 47shift상류수위(EL.m)
# 0.0 48shift상류수위(EL.m)
# 0.0 49shift상류수위(EL.m)
# 0.0 50shift상류수위(EL.m)
# 0.0 51shift상류수위(EL.m)
# 0.0 52shift상류수위(EL.m)
# 0.0 53shift상류수위(EL.m)
# 0.0 54shift상류수위(EL.m)
# 0.0 55shift상류수위(EL.m)
# 0.0 56shift상류수위(EL.m)
# 0.0 57shift상류수위(EL.m)
# 0.0 58shift상류수위(EL.m)
# 0.0 59shift상류수위(EL.m)
# 0.0 60shift상류수위(EL.m)
# 0.0 61shift상류수위(EL.m)
# 0.0 62shift상류수위(EL.m)
# 0.0 63shift상류수위(EL.m)
# 0.0 64shift상류수위(EL.m)
# 0.0 65shift상류수위(EL.m)
# 0.0 66shift상류수위(EL.m)
# 0.0 67shift상류수위(EL.m)
# 0.0 68shift상류수위(EL.m)
# 0.0 69shift상류수위(EL.m)
# 0.0 70shift상류수위(EL.m)
# 0.0 71shift상류수위(EL.m)
# 0.0 72shift상류수위(EL.m)
# 0.01 1shift방류량(㎥/s)
# 0.0 2shift방류량(㎥/s)
# 0.0 3shift방류량(㎥/s)
# 0.0 4shift방류량(㎥/s)
# 0.0 5shift방류량(㎥/s)
# 0.0 6shift방류량(㎥/s)
# 0.0 7shift방류량(㎥/s)
# 0.0 8shift방류량(㎥/s)
# 0.0 9shift방류량(㎥/s)
# 0.0 10shift방류량(㎥/s)
# 0.0 11shift방류량(㎥/s)
# 0.0 12shift방류량(㎥/s)
# 0.0 13shift방류량(㎥/s)
# 0.0 14shift방류량(㎥/s)
# 0.0 15shift방류량(㎥/s)
# 0.0 16shift방류량(㎥/s)
# 0.01 17shift방류량(㎥/s)
# 0.01 18shift방류량(㎥/s)
# 0.0 19shift방류량(㎥/s)
# 0.0 20shift방류량(㎥/s)
# 0.0 21shift방류량(㎥/s)
# 0.01 22shift방류량(㎥/s)
# 0.01 23shift방류량(㎥/s)
# 0.0 24shift방류량(㎥/s)
# 0.0 25shift방류량(㎥/s)
# 0.0 26shift방류량(㎥/s)
# 0.0 27shift방류량(㎥/s)
# 0.01 28shift방류량(㎥/s)
# 0.0 29shift방류량(㎥/s)
# 0.0 30shift방류량(㎥/s)
# 0.0 31shift방류량(㎥/s)
# 0.0 32shift방류량(㎥/s)
# 0.0 33shift방류량(㎥/s)
# 0.0 34shift방류량(㎥/s)
# 0.0 35shift방류량(㎥/s)
# 0.0 36shift방류량(㎥/s)
# 0.0 37shift방류량(㎥/s)
# 0.0 38shift방류량(㎥/s)
# 0.0 39shift방류량(㎥/s)
# 0.0 40shift방류량(㎥/s)
# 0.0 41shift방류량(㎥/s)
# 0.0 42shift방류량(㎥/s)
# 0.0 43shift방류량(㎥/s)
# 0.0 44shift방류량(㎥/s)
# 0.0 45shift방류량(㎥/s)
# 0.0 46shift방류량(㎥/s)
# 0.0 47shift방류량(㎥/s)
# 0.0 48shift방류량(㎥/s)
# 0.0 49shift방류량(㎥/s)
# 0.0 50shift방류량(㎥/s)
# 0.0 51shift방류량(㎥/s)
# 0.0 52shift방류량(㎥/s)
# 0.0 53shift방류량(㎥/s)
# 0.0 54shift방류량(㎥/s)
# 0.0 55shift방류량(㎥/s)
# 0.0 56shift방류량(㎥/s)
# 0.0 57shift방류량(㎥/s)
# 0.0 58shift방류량(㎥/s)
# 0.0 59shift방류량(㎥/s)
# 0.0 60shift방류량(㎥/s)
# 0.0 61shift방류량(㎥/s)
# 0.0 62shift방류량(㎥/s)
# 0.0 63shift방류량(㎥/s)
# 0.0 64shift방류량(㎥/s)
# 0.0 65shift방류량(㎥/s)
# 0.0 66shift방류량(㎥/s)
# 0.0 67shift방류량(㎥/s)
# 0.0 68shift방류량(㎥/s)
# 0.0 69shift방류량(㎥/s)
# 0.0 70shift방류량(㎥/s)
# 0.0 71shift방류량(㎥/s)
# 0.0 72shift방류량(㎥/s)

# %%
feature_series = pd.Series(data = estimator.feature_importances_, index = col_v)
feature_series = feature_series.sort_values(ascending = False)
sns.barplot(x = feature_series[:10], y = feature_series.index[:10], color = 'gray')
plt.show()

# %%
feature_series[:10]
# Out:
# 수소이온농도               0.139481
# 전기전도도 μS/cm          0.071048
# 1shift전기전도도 μS/cm    0.068280
# 1shift수소이온농도         0.059999
# 용존산소 mg/L            0.047230
# 2shift수소이온농도         0.024333
# 수온 ℃                 0.023039
# 3shift수소이온농도         0.017241
# 16shift수온 ℃          0.013885
# 2shift수온 ℃           0.011786
# dtype: float64

# %%
print('score :', estimator.score(X_test, np.log1p(y_test)))
# Out:
# score : 0.9683495979233097

# %% [markdown]
# 피처 정규화

# %%
scaler = StandardScaler()
scaler.fit(scb_df.loc[:, col_v])
scb_scaled = scaler.transform(scb_df.loc[:, col_v])

scb_df_scaled = pd.DataFrame(data = scb_scaled, columns = col_v)

# %%
scb_df_scaled.head()
# Out:
#        수온 ℃    수소이온농도  전기전도도 μS/cm  용존산소 mg/L  총유기탄소 mg/L  총질소 mg/L   총인 mg/L  \
# 0 -0.460123 -0.371802    -0.204436  -0.384734   -1.066592  0.701736 -0.404844
# 1 -0.460123 -0.371802    -0.170395  -0.384734   -1.066592  0.762211 -0.404844
# 2 -0.512399 -0.371802    -0.181742  -0.464263   -1.066592  0.826214 -0.419518
# 3 -0.538537 -0.371802    -0.159048  -0.464263   -1.066592  0.852420 -0.448867
# 4 -0.551606 -0.371802    -0.125007  -0.490773   -1.066592  0.797992 -0.463541
#
#    상류수위(EL.m)  방류량(㎥/s)  1shift수온 ℃  ...  39shift방류량(㎥/s)  40shift방류량(㎥/s)  \
# 0    0.712847 -0.173164   -0.447041  ...        -0.155560        -0.155034
# 1    0.712847 -0.173164   -0.460110  ...        -0.155750        -0.155560
# 2    0.712847 -0.173485   -0.460110  ...        -0.156451        -0.155750
# 3    0.712847 -0.173544   -0.512387  ...        -0.156495        -0.156451
# 4    0.712847 -0.173661   -0.538525  ...        -0.156626        -0.156495
#
#    41shift방류량(㎥/s)  42shift방류량(㎥/s)  43shift방류량(㎥/s)  44shift방류량(㎥/s)  \
# 0        -0.154976        -0.154553        -0.154305        -0.153998
# 1        -0.155035        -0.154976        -0.154553        -0.154305
# 2        -0.155560        -0.155035        -0.154977        -0.154553
# 3        -0.155750        -0.155561        -0.155035        -0.154977
# 4        -0.156451        -0.155750        -0.155561        -0.155035
#
#    45shift방류량(㎥/s)  46shift방류량(㎥/s)  47shift방류량(㎥/s)  48shift방류량(㎥/s)
# 0        -0.147588        -0.142098        -0.165740        -0.173903
# 1        -0.153999        -0.147588        -0.142098        -0.165740
# 2        -0.154305        -0.153999        -0.147588        -0.142098
# 3        -0.154554        -0.154306        -0.153999        -0.147588
# 4        -0.154977        -0.154554        -0.154306        -0.153999
#
# [5 rows x 441 columns]

# %%
X_trains, X_tests, y_trains, y_tests = train_test_split(scb_df_scaled.loc[:, col_v], scb_df['클로로필-a mg/㎥'], random_state=42)
gb_regs = GradientBoostingRegressor(random_state=42)

parameters = {'max_depth':[5, 10, 15], 'learning_rate':[0.05, 0.1, 0.2]}

# %%
gb_grids = GridSearchCV(gb_regs, param_grid=parameters, cv=3)

# %%
gb_grids.fit(X_trains, np.log1p(y_trains))

# %%
scores_dfs = pd.DataFrame(gb_grids.cv_results_)

# %%
scores_dfs.sort_values(by=['rank_test_score'], inplace=True)
scores_dfs[['params', 'mean_test_score', 'rank_test_score']].head()

# %%
gb_grids.best_params_

# %%
estimators = gb_grids.best_estimator_

# %%
preds = estimators.predict(X_tests)

# %%
for score, name in zip(estimators.feature_importances_, col_v):
    print(round(score, 2), name)

# %%
feature_seriess = pd.Series(data = estimators.feature_importances_, index = col_v)
feature_seriess = feature_seriess.sort_values(ascending = False)
sns.barplot(x = feature_seriess[:10], y = feature_seriess.index[:10], color = 'gray')
plt.show()

# %%
feature_seriess[:10]

# %%
print('score :', estimators.score(X_tests, np.log1p(y_tests)))
