# %% [markdown]
# 필요한 모듈 임포트

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
import platform
plt.rc('figure', figsize=(10, 6))  # 그림 크기 설정
if platform.system() == 'Windows': # 윈도우
    from matplotlib import font_manager, rc
    font_path = "C:/Windows/Fonts/NGULIM.TTF"
    font = font_manager.FontProperties(fname=font_path).get_name()
    rc('font', family=font)
elif platform.system() == 'Linux': # 우분투 또는 구글 코랩
    # !sudo apt-get install -y fonts-nanum*
    # !fc-cache -fv
    
    applyfont = "NanumBarunGothic"
    import matplotlib.font_manager as fm
    if not any(map(lambda ft: ft.name == applyfont, fm.fontManager.ttflist)):
        fm.fontManager.addfont("/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf")
    plt.rc("font", family=applyfont)
    plt.rc("axes", unicode_minus=False)

# %%
# GradientBoosting
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# 데이터 가져오기

# %%
base_path = "https://github.com/codingalzi/water-data/raw/master/reservoirs/"
# base_path = r"C:\Users\owner\Desktop\water-source\data"

# %%
# jsb_yearly = pd.read_excel(base_path+"\Jugsanbo.xlsx", 
jsb_yearly = pd.read_excel(base_path+"Jugsanbo.xlsx", 
                            skiprows=0, 
                            header=1, 
                            sheet_name=None,
                            na_values='ND',
                            parse_dates=True)  # index_col = 0을 제외함

# %%
print(type(jsb_yearly))  # type-dict
print(jsb_yearly.keys())  # 2012년부터 2022년까지
# Out:
# <class 'dict'>
# dict_keys(['2012년', '2013년', '2014년', '2015년', '2016년', '2017년', '2018년', '2019년', '2020년', '2021년', '2022년'])

# %%
jsb_yearly['2012년'].columns
# Out:
# Index(['측정일/월', '측정소명', '수온 ℃', '수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L', '탁도 NTU',
#        '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L', '클로로필-a mg/㎥'],
#       dtype='object')

# %% [markdown]
# 2013년 자료부터

# %%
jsb_yearly_df13 = pd.DataFrame()

for item in list(jsb_yearly.keys())[1:]:
    jsb_yearly_df13 = pd.concat([jsb_yearly_df13, jsb_yearly[item]])

# %%
jsb_yearly_df13 = jsb_yearly_df13.reset_index(drop=True)

# %% [markdown]
# 결측치 확인

# %%
jsb_yearly_df13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82064 entries, 0 to 82063
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   측정일/월        82064 non-null  object
#  1   측정소명         82064 non-null  object
#  2   수온 ℃         71955 non-null  float64
#  3   수소이온농도       72092 non-null  float64
#  4   전기전도도 μS/cm  72139 non-null  float64
#  5   용존산소 mg/L    70998 non-null  float64
#  6   탁도 NTU       71312 non-null  float64
#  7   총유기탄소 mg/L   66051 non-null  float64
#  8   총질소 mg/L     67124 non-null  float64
#  9   총인 mg/L      67772 non-null  float64
#  10  클로로필-a mg/㎥  69643 non-null  float64
# dtypes: float64(9), object(2)
# memory usage: 6.9+ MB

# %%
jsb_yearly_df13.isnull().sum()
# Out:
# 측정일/월              0
# 측정소명               0
# 수온 ℃           10109
# 수소이온농도          9972
# 전기전도도 μS/cm     9925
# 용존산소 mg/L      11066
# 탁도 NTU         10752
# 총유기탄소 mg/L     16013
# 총질소 mg/L       14940
# 총인 mg/L        14292
# 클로로필-a mg/㎥    12421
# dtype: int64

# %%
jsb_yearly_df13.head()
# Out:
#             측정일/월 측정소명  수온 ℃  수소이온농도  전기전도도 μS/cm  용존산소 mg/L  탁도 NTU  \
# 0  2013-01-01 00h   나주   3.3     6.8        272.0       12.0     1.8
# 1  2013-01-01 01h   나주   3.1     6.7        272.0       12.0     1.7
# 2  2013-01-01 02h   나주   3.0     6.7        273.0       12.0     1.7
# 3  2013-01-01 03h   나주   3.0     6.7        275.0       12.0     1.6
# 4  2013-01-01 04h   나주   2.9     6.7        276.0       12.0     1.5
#
#    총유기탄소 mg/L  총질소 mg/L  총인 mg/L  클로로필-a mg/㎥
# 0         1.9       NaN      NaN         12.2
# 1         1.9       NaN      NaN         12.0
# 2         1.9       NaN      NaN         12.1
# 3         1.9       NaN      NaN         12.2
# 4         1.9       NaN      NaN         12.1

# %% [markdown]
# 유량 데이터 추가하기

# %%
# jsb_flow_yearly = pd.read_excel(base_path+"\Jugsanbo_flow.xlsx", 
jsb_flow_yearly = pd.read_excel(base_path+"Jugsanbo_flow.xlsx", 
                            header=0, 
                            sheet_name=None,
                            na_values='ND',
                            parse_dates=True)  # index_col = 0을 제외함

# %%
for year in list(jsb_flow_yearly.keys())[1:]:
    jsb_flow_yearly[year]['연월일시'] = jsb_flow_yearly[year]['시간'].apply(lambda x : x[:-3])

# %%
jsb_flow_yearly_hour = {}

for year in list(jsb_flow_yearly.keys())[1:]:
    jsb_flow_yearly_hour[year] = jsb_flow_yearly[year].groupby('연월일시').mean()

# %%
for year in jsb_flow_yearly_hour:
    jsb_flow_yearly_hour[year] = jsb_flow_yearly_hour[year].reset_index()

# %%
jsb_flow_yearly_hour_df = pd.DataFrame()

for year in jsb_flow_yearly_hour:
    jsb_flow_yearly_hour_df = pd.concat([jsb_flow_yearly_hour_df, jsb_flow_yearly_hour[year]])

# %%
jsb_flow_yearly_hour_df = jsb_flow_yearly_hour_df.reset_index(drop=True)

# %%
print(jsb_flow_yearly_hour_df.__len__())
print(jsb_yearly_df13.__len__())
# Out:
# 84462
# 82064

# %%
jsb_yearly_df13['연월일시'] = jsb_yearly_df13['측정일/월'].transform(lambda x: x.strip('h').replace('-', '.'))

# %%
jsb_data = pd.merge(jsb_yearly_df13, jsb_flow_yearly_hour_df, how='outer')

# %%
jsb_data = jsb_data[:82064]

# %%
jsb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82064 entries, 0 to 82063
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   측정일/월        82064 non-null  object
#  1   측정소명         82064 non-null  object
#  2   수온 ℃         71955 non-null  float64
#  3   수소이온농도       72092 non-null  float64
#  4   전기전도도 μS/cm  72139 non-null  float64
#  5   용존산소 mg/L    70998 non-null  float64
#  6   탁도 NTU       71312 non-null  float64
#  7   총유기탄소 mg/L   66051 non-null  float64
#  8   총질소 mg/L     67124 non-null  float64
#  9   총인 mg/L      67772 non-null  float64
#  10  클로로필-a mg/㎥  69643 non-null  float64
#  11  연월일시         82064 non-null  object
#  12   상류수위(EL.m)  82051 non-null  float64
#  13   하류수위(EL.m)  82051 non-null  float64
#  14   유입량(㎥/s)    82051 non-null  float64
#  15   방류량(㎥/s)    82051 non-null  float64
# dtypes: float64(13), object(3)
# memory usage: 10.6+ MB

# %%
jsb_data.columns = [x.strip() for x in list(jsb_data.columns)]

# %%
jsb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82064 entries, 0 to 82063
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   측정일/월        82064 non-null  object
#  1   측정소명         82064 non-null  object
#  2   수온 ℃         71955 non-null  float64
#  3   수소이온농도       72092 non-null  float64
#  4   전기전도도 μS/cm  72139 non-null  float64
#  5   용존산소 mg/L    70998 non-null  float64
#  6   탁도 NTU       71312 non-null  float64
#  7   총유기탄소 mg/L   66051 non-null  float64
#  8   총질소 mg/L     67124 non-null  float64
#  9   총인 mg/L      67772 non-null  float64
#  10  클로로필-a mg/㎥  69643 non-null  float64
#  11  연월일시         82064 non-null  object
#  12  상류수위(EL.m)   82051 non-null  float64
#  13  하류수위(EL.m)   82051 non-null  float64
#  14  유입량(㎥/s)     82051 non-null  float64
#  15  방류량(㎥/s)     82051 non-null  float64
# dtypes: float64(13), object(3)
# memory usage: 10.6+ MB

# %%
list(jsb_data.columns)[:-5] + list(jsb_data.columns)[-4:-3] + list(jsb_data.columns)[-1:]
# Out:
# ['측정일/월',
#  '측정소명',
#  '수온 ℃',
#  '수소이온농도',
#  '전기전도도 μS/cm',
#  '용존산소 mg/L',
#  '탁도 NTU',
#  '총유기탄소 mg/L',
#  '총질소 mg/L',
#  '총인 mg/L',
#  '클로로필-a mg/㎥',
#  '상류수위(EL.m)',
#  '방류량(㎥/s)']

# %%
jsb_data = jsb_data.loc[:, list(jsb_data.columns)[:-5] + list(jsb_data.columns)[-4:-3] + list(jsb_data.columns)[-1:]]

# %%
jsb_data.columns
# Out:
# Index(['측정일/월', '측정소명', '수온 ℃', '수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L', '탁도 NTU',
#        '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L', '클로로필-a mg/㎥', '상류수위(EL.m)',
#        '방류량(㎥/s)'],
#       dtype='object')

# %%
jsb_data.isnull().sum()
# Out:
# 측정일/월              0
# 측정소명               0
# 수온 ℃           10109
# 수소이온농도          9972
# 전기전도도 μS/cm     9925
# 용존산소 mg/L      11066
# 탁도 NTU         10752
# 총유기탄소 mg/L     16013
# 총질소 mg/L       14940
# 총인 mg/L        14292
# 클로로필-a mg/㎥    12421
# 상류수위(EL.m)        13
# 방류량(㎥/s)          13
# dtype: int64

# %%
jsb_data.isnull().sum() /len(jsb_data)
# Out:
# 측정일/월          0.000000
# 측정소명           0.000000
# 수온 ℃           0.123184
# 수소이온농도         0.121515
# 전기전도도 μS/cm    0.120942
# 용존산소 mg/L      0.134846
# 탁도 NTU         0.131020
# 총유기탄소 mg/L     0.195128
# 총질소 mg/L       0.182053
# 총인 mg/L        0.174157
# 클로로필-a mg/㎥    0.151357
# 상류수위(EL.m)     0.000158
# 방류량(㎥/s)       0.000158
# dtype: float64

# %%
len(jsb_data)
# Out:
# 82064

# %% [markdown]
# 시간데이터 추가

# %%
jsb_df = jsb_data.copy()

# %%
jsb_df.columns
# Out:
# Index(['측정일/월', '측정소명', '수온 ℃', '수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L', '탁도 NTU',
#        '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L', '클로로필-a mg/㎥', '상류수위(EL.m)',
#        '방류량(㎥/s)'],
#       dtype='object')

# %%
col_c = list(jsb_df.columns.copy())
col_c.remove('클로로필-a mg/㎥')

# %%
col_c
# Out:
# ['측정일/월',
#  '측정소명',
#  '수온 ℃',
#  '수소이온농도',
#  '전기전도도 μS/cm',
#  '용존산소 mg/L',
#  '탁도 NTU',
#  '총유기탄소 mg/L',
#  '총질소 mg/L',
#  '총인 mg/L',
#  '상류수위(EL.m)',
#  '방류량(㎥/s)']

# %%
for var in col_c[2:]:
    for i in range(1, 73):
        jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# Out:
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# ...
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)
# C:\Users\gslee\AppData\Local\Temp\ipykernel_23388\3671321184.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   jsb_df[str(i) + 'shift' + var] = jsb_df[var].shift(i)

# %%
len(jsb_df)
# Out:
# 82064

# %%
jsb_df.columns
# Out:
# Index(['측정일/월', '측정소명', '수온 ℃', '수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L', '탁도 NTU',
#        '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L',
#        ...
#        '63shift방류량(㎥/s)', '64shift방류량(㎥/s)', '65shift방류량(㎥/s)',
#        '66shift방류량(㎥/s)', '67shift방류량(㎥/s)', '68shift방류량(㎥/s)',
#        '69shift방류량(㎥/s)', '70shift방류량(㎥/s)', '71shift방류량(㎥/s)',
#        '72shift방류량(㎥/s)'],
#       dtype='object', length=733)

# %%
len(jsb_df)
# Out:
# 82064

# %% [markdown]
# 결측치 보간법

# %%
from datetime import datetime

# %%
jsb_df = jsb_df.copy()

# %%
jsb_df['측정일/월'] = jsb_df['측정일/월'].transform(lambda x: datetime.strptime(x[:-1], '%Y-%m-%d %H'))

# %%
jsb_df = jsb_df.copy().set_index('측정일/월').interpolate(method='time')

# %%
jsb_df = jsb_df.dropna()

# %%
jsb_df.__len__()
# Out:
# 79891

# %%
jsb_df.columns
# Out:
# Index(['측정소명', '수온 ℃', '수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L', '탁도 NTU',
#        '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L', '클로로필-a mg/㎥',
#        ...
#        '63shift방류량(㎥/s)', '64shift방류량(㎥/s)', '65shift방류량(㎥/s)',
#        '66shift방류량(㎥/s)', '67shift방류량(㎥/s)', '68shift방류량(㎥/s)',
#        '69shift방류량(㎥/s)', '70shift방류량(㎥/s)', '71shift방류량(㎥/s)',
#        '72shift방류량(㎥/s)'],
#       dtype='object', length=732)

# %%
col = list(jsb_df.columns[2:])
print(col)
# Out:
# ['수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L', '탁도 NTU', '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L', '클로로필-a mg/㎥', '상류수위(EL.m)', '방류량(㎥/s)', '1shift수온 ℃', '2shift수온 ℃', '3shift수온 ℃', '4shift수온 ℃', '5shift수온 ℃', '6shift수온 ℃', '7shift수온 ℃', '8shift수온 ℃', '9shift수온 ℃', '10shift수온 ℃', '11shift수온 ℃', '12shift수온 ℃', '13shift수온 ℃', '14shift수온 ℃', '15shift수온 ℃', '16shift수온 ℃', '17shift수온 ℃', '18shift수온 ℃', '19shift수온 ℃', '20shift수온 ℃', '21shift수온 ℃', '22shift수온 ℃', '23shift수온 ℃', '24shift수온 ℃', '25shift수온 ℃', '26shift수온 ℃', '27shift수온 ℃', '28shift수온 ℃', '29shift수온 ℃', '30shift수온 ℃', '31shift수온 ℃', '32shift수온 ℃', '33shift수온 ℃', '34shift수온 ℃', '35shift수온 ℃', '36shift수온 ℃', '37shift수온 ℃', '38shift수온 ℃', '39shift수온 ℃', '40shift수온 ℃', '41shift수온 ℃', '42shift수온 ℃', '43shift수온 ℃', '44shift수온 ℃', '45shift수온 ℃', '46shift수온 ℃', '47shift수온 ℃', '48shift수온 ℃', '49shift수온 ℃', '50shift수온 ℃', '51shift수온 ℃', '52shift수온 ℃', '53shift수온 ℃', '54shift수온 ℃', '55shift수온 ℃', '56shift수온 ℃', '57shift수온 ℃', '58shift수온 ℃', '59shift수온 ℃', '60shift수온 ℃', '61shift수온 ℃', '62shift수온 ℃', '63shift수온 ℃', '64shift수온 ℃', '65shift수온 ℃', '66shift수온 ℃', '67shift수온 ℃', '68shift수온 ℃', '69shift수온 ℃', '70shift수온 ℃', '71shift수온 ℃', '72shift수온 ℃', '1shift수소이온농도', '2shift수소이온농도', '3shift수소이온농도', '4shift수소이온농도', '5shift수소이온농도', '6shift수소이온농도', '7shift수소이온농도', '8shift수소이온농도', '9shift수소이온농도', '10shift수소이온농도', '11shift수소이온농도', '12shift수소이온농도', '13shift수소이온농도', '14shift수소이온농도', '15shift수소이온농도', '16shift수소이온농도', '17shift수소이온농도', '18shift수소이온농도', '19shift수소이온농도', '20shift수소이온농도', '21shift수소이온농도', '22shift수소이온농도', '23shift수소이온농도', '24shift수소이온농도', '25shift수소이온농도', '26shift수소이온농도', '27shift수소이온농도', '28shift수소이온농도', '29shift수소이온농도', '30shift수소이온농도', '31shift수소이온농도', '32shift수소이온농도', '33shift수소이온농도', '34shift수소이온농도', '35shift수소이온농도', '36shift수소이온농도', '37shift수소이온농도', '38shift수소이온농도', '39shift수소이온농도', '40shift수소이온농도', '41shift수소이온농도', '42shift수소이온농도', '43shift수소이온농도', '44shift수소이온농도', '45shift수소이온농도', '46shift수소이온농도', '47shift수소이온농도', '48shift수소이온농도', '49shift수소이온농도', '50shift수소이온농도', '51shift수소이온농도', '52shift수소이온농도', '53shift수소이온농도', '54shift수소이온농도', '55shift수소이온농도', '56shift수소이온농도', '57shift수소이온농도', '58shift수소이온농도', '59shift수소이온농도', '60shift수소이온농도', '61shift수소이온농도', '62shift수소이온농도', '63shift수소이온농도', '64shift수소이온농도', '65shift수소이온농도', '66shift수소이온농도', '67shift수소이온농도', '68shift수소이온농도', '69shift수소이온농도', '70shift수소이온농도', '71shift수소이온농도', '72shift수소이온농도', '1shift전기전도도 μS/cm', '2shift전기전도도 μS/cm', '3shift전기전도도 μS/cm', '4shift전기전도도 μS/cm', '5shift전기전도도 μS/cm', '6shift전기전도도 μS/cm', '7shift전기전도도 μS/cm', '8shift전기전도도 μS/cm', '9shift전기전도도 μS/cm', '10shift전기전도도 μS/cm', '11shift전기전도도 μS/cm', '12shift전기전도도 μS/cm', '13shift전기전도도 μS/cm', '14shift전기전도도 μS/cm', '15shift전기전도도 μS/cm', '16shift전기전도도 μS/cm', '17shift전기전도도 μS/cm', '18shift전기전도도 μS/cm', '19shift전기전도도 μS/cm', '20shift전기전도도 μS/cm', '21shift전기전도도 μS/cm', '22shift전기전도도 μS/cm', '23shift전기전도도 μS/cm', '24shift전기전도도 μS/cm', '25shift전기전도도 μS/cm', '26shift전기전도도 μS/cm', '27shift전기전도도 μS/cm', '28shift전기전도도 μS/cm', '29shift전기전도도 μS/cm', '30shift전기전도도 μS/cm', '31shift전기전도도 μS/cm', '32shift전기전도도 μS/cm', '33shift전기전도도 μS/cm', '34shift전기전도도 μS/cm', '35shift전기전도도 μS/cm', '36shift전기전도도 μS/cm', '37shift전기전도도 μS/cm', '38shift전기전도도 μS/cm', '39shift전기전도도 μS/cm', '40shift전기전도도 μS/cm', '41shift전기전도도 μS/cm', '42shift전기전도도 μS/cm', '43shift전기전도도 μS/cm', '44shift전기전도도 μS/cm', '45shift전기전도도 μS/cm', '46shift전기전도도 μS/cm', '47shift전기전도도 μS/cm', '48shift전기전도도 μS/cm', '49shift전기전도도 μS/cm', '50shift전기전도도 μS/cm', '51shift전기전도도 μS/cm', '52shift전기전도도 μS/cm', '53shift전기전도도 μS/cm', '54shift전기전도도 μS/cm', '55shift전기전도도 μS/cm', '56shift전기전도도 μS/cm', '57shift전기전도도 μS/cm', '58shift전기전도도 μS/cm', '59shift전기전도도 μS/cm', '60shift전기전도도 μS/cm', '61shift전기전도도 μS/cm', '62shift전기전도도 μS/cm', '63shift전기전도도 μS/cm', '64shift전기전도도 μS/cm', '65shift전기전도도 μS/cm', '66shift전기전도도 μS/cm', '67shift전기전도도 μS/cm', '68shift전기전도도 μS/cm', '69shift전기전도도 μS/cm', '70shift전기전도도 μS/cm', '71shift전기전도도 μS/cm', '72shift전기전도도 μS/cm', '1shift용존산소  ...

# %%
col_v = col.copy()
col_v.remove('클로로필-a mg/㎥')
print(col_v)
# Out:
# ['수소이온농도', '전기전도도 μS/cm', '용존산소 mg/L', '탁도 NTU', '총유기탄소 mg/L', '총질소 mg/L', '총인 mg/L', '상류수위(EL.m)', '방류량(㎥/s)', '1shift수온 ℃', '2shift수온 ℃', '3shift수온 ℃', '4shift수온 ℃', '5shift수온 ℃', '6shift수온 ℃', '7shift수온 ℃', '8shift수온 ℃', '9shift수온 ℃', '10shift수온 ℃', '11shift수온 ℃', '12shift수온 ℃', '13shift수온 ℃', '14shift수온 ℃', '15shift수온 ℃', '16shift수온 ℃', '17shift수온 ℃', '18shift수온 ℃', '19shift수온 ℃', '20shift수온 ℃', '21shift수온 ℃', '22shift수온 ℃', '23shift수온 ℃', '24shift수온 ℃', '25shift수온 ℃', '26shift수온 ℃', '27shift수온 ℃', '28shift수온 ℃', '29shift수온 ℃', '30shift수온 ℃', '31shift수온 ℃', '32shift수온 ℃', '33shift수온 ℃', '34shift수온 ℃', '35shift수온 ℃', '36shift수온 ℃', '37shift수온 ℃', '38shift수온 ℃', '39shift수온 ℃', '40shift수온 ℃', '41shift수온 ℃', '42shift수온 ℃', '43shift수온 ℃', '44shift수온 ℃', '45shift수온 ℃', '46shift수온 ℃', '47shift수온 ℃', '48shift수온 ℃', '49shift수온 ℃', '50shift수온 ℃', '51shift수온 ℃', '52shift수온 ℃', '53shift수온 ℃', '54shift수온 ℃', '55shift수온 ℃', '56shift수온 ℃', '57shift수온 ℃', '58shift수온 ℃', '59shift수온 ℃', '60shift수온 ℃', '61shift수온 ℃', '62shift수온 ℃', '63shift수온 ℃', '64shift수온 ℃', '65shift수온 ℃', '66shift수온 ℃', '67shift수온 ℃', '68shift수온 ℃', '69shift수온 ℃', '70shift수온 ℃', '71shift수온 ℃', '72shift수온 ℃', '1shift수소이온농도', '2shift수소이온농도', '3shift수소이온농도', '4shift수소이온농도', '5shift수소이온농도', '6shift수소이온농도', '7shift수소이온농도', '8shift수소이온농도', '9shift수소이온농도', '10shift수소이온농도', '11shift수소이온농도', '12shift수소이온농도', '13shift수소이온농도', '14shift수소이온농도', '15shift수소이온농도', '16shift수소이온농도', '17shift수소이온농도', '18shift수소이온농도', '19shift수소이온농도', '20shift수소이온농도', '21shift수소이온농도', '22shift수소이온농도', '23shift수소이온농도', '24shift수소이온농도', '25shift수소이온농도', '26shift수소이온농도', '27shift수소이온농도', '28shift수소이온농도', '29shift수소이온농도', '30shift수소이온농도', '31shift수소이온농도', '32shift수소이온농도', '33shift수소이온농도', '34shift수소이온농도', '35shift수소이온농도', '36shift수소이온농도', '37shift수소이온농도', '38shift수소이온농도', '39shift수소이온농도', '40shift수소이온농도', '41shift수소이온농도', '42shift수소이온농도', '43shift수소이온농도', '44shift수소이온농도', '45shift수소이온농도', '46shift수소이온농도', '47shift수소이온농도', '48shift수소이온농도', '49shift수소이온농도', '50shift수소이온농도', '51shift수소이온농도', '52shift수소이온농도', '53shift수소이온농도', '54shift수소이온농도', '55shift수소이온농도', '56shift수소이온농도', '57shift수소이온농도', '58shift수소이온농도', '59shift수소이온농도', '60shift수소이온농도', '61shift수소이온농도', '62shift수소이온농도', '63shift수소이온농도', '64shift수소이온농도', '65shift수소이온농도', '66shift수소이온농도', '67shift수소이온농도', '68shift수소이온농도', '69shift수소이온농도', '70shift수소이온농도', '71shift수소이온농도', '72shift수소이온농도', '1shift전기전도도 μS/cm', '2shift전기전도도 μS/cm', '3shift전기전도도 μS/cm', '4shift전기전도도 μS/cm', '5shift전기전도도 μS/cm', '6shift전기전도도 μS/cm', '7shift전기전도도 μS/cm', '8shift전기전도도 μS/cm', '9shift전기전도도 μS/cm', '10shift전기전도도 μS/cm', '11shift전기전도도 μS/cm', '12shift전기전도도 μS/cm', '13shift전기전도도 μS/cm', '14shift전기전도도 μS/cm', '15shift전기전도도 μS/cm', '16shift전기전도도 μS/cm', '17shift전기전도도 μS/cm', '18shift전기전도도 μS/cm', '19shift전기전도도 μS/cm', '20shift전기전도도 μS/cm', '21shift전기전도도 μS/cm', '22shift전기전도도 μS/cm', '23shift전기전도도 μS/cm', '24shift전기전도도 μS/cm', '25shift전기전도도 μS/cm', '26shift전기전도도 μS/cm', '27shift전기전도도 μS/cm', '28shift전기전도도 μS/cm', '29shift전기전도도 μS/cm', '30shift전기전도도 μS/cm', '31shift전기전도도 μS/cm', '32shift전기전도도 μS/cm', '33shift전기전도도 μS/cm', '34shift전기전도도 μS/cm', '35shift전기전도도 μS/cm', '36shift전기전도도 μS/cm', '37shift전기전도도 μS/cm', '38shift전기전도도 μS/cm', '39shift전기전도도 μS/cm', '40shift전기전도도 μS/cm', '41shift전기전도도 μS/cm', '42shift전기전도도 μS/cm', '43shift전기전도도 μS/cm', '44shift전기전도도 μS/cm', '45shift전기전도도 μS/cm', '46shift전기전도도 μS/cm', '47shift전기전도도 μS/cm', '48shift전기전도도 μS/cm', '49shift전기전도도 μS/cm', '50shift전기전도도 μS/cm', '51shift전기전도도 μS/cm', '52shift전기전도도 μS/cm', '53shift전기전도도 μS/cm', '54shift전기전도도 μS/cm', '55shift전기전도도 μS/cm', '56shift전기전도도 μS/cm', '57shift전기전도도 μS/cm', '58shift전기전도도 μS/cm', '59shift전기전도도 μS/cm', '60shift전기전도도 μS/cm', '61shift전기전도도 μS/cm', '62shift전기전도도 μS/cm', '63shift전기전도도 μS/cm', '64shift전기전도도 μS/cm', '65shift전기전도도 μS/cm', '66shift전기전도도 μS/cm', '67shift전기전도도 μS/cm', '68shift전기전도도 μS/cm', '69shift전기전도도 μS/cm', '70shift전기전도도 μS/cm', '71shift전기전도도 μS/cm', '72shift전기전도도 μS/cm', '1shift용존산소 mg/L', '2shift용 ...

# %% [markdown]
# 피처 정규화 없이

# %%
X_train, X_test, y_train, y_test = train_test_split(jsb_df.loc[:, col_v], jsb_df['클로로필-a mg/㎥'], random_state=42)
gb_reg = GradientBoostingRegressor(random_state=42)

parameters = {'max_depth':[10], 'learning_rate':[0.05]}
# parameters = {'max_depth':[5, 10, 15], 'learning_rate':[0.05, 0.1, 0.2]}

# %%
gb_grid = GridSearchCV(gb_reg, param_grid=parameters, cv=3, verbose=5)

# %%
gb_grid.fit(X_train, np.log1p(y_train))
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ..learning_rate=0.05, max_depth=10;, score=0.967 total time=34.0min
# [CV 2/3] END ..learning_rate=0.05, max_depth=10;, score=0.967 total time=34.5min
# [CV 3/3] END ..learning_rate=0.05, max_depth=10;, score=0.968 total time=34.6min
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(random_state=42),
#              param_grid={'learning_rate': [0.05], 'max_depth': [10]},
#              verbose=5)

# %%
scores_df = pd.DataFrame(gb_grid.cv_results_)

# %%
scores_df.sort_values(by=['rank_test_score'], inplace=True)
scores_df[['params', 'mean_test_score', 'rank_test_score']].head()
# Out:
#                                      params  mean_test_score  rank_test_score
# 0  {'learning_rate': 0.05, 'max_depth': 10}         0.967263                1

# %%
gb_grid.best_params_s
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\gslee\Documents\GitHub\water-data\reservoirs\time_interpolation\Jugsanbo72_220916.ipynb 셀 63 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gslee/Documents/GitHub/water-data/reservoirs/time_interpolation/Jugsanbo72_220916.ipynb#Y116sZmlsZQ%3D%3D?line=0'>1</a> gb_grid.best_params_s
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_s'

# %%
estimator = gb_grid.best_estimator_

# %%
pred = estimator.predict(X_test)

# %%
for score, name in zip(estimator.feature_importances_, col_v):
    print(round(score, 2), name)
# Out:
# 0.4 수소이온농도
# 0.01 전기전도도 μS/cm
# 0.1 용존산소 mg/L
# 0.03 탁도 NTU
# 0.03 총유기탄소 mg/L
# 0.02 총질소 mg/L
# 0.0 총인 mg/L
# 0.0 상류수위(EL.m)
# 0.0 방류량(㎥/s)
# 0.02 1shift수온 ℃
# 0.0 2shift수온 ℃
# 0.0 3shift수온 ℃
# 0.0 4shift수온 ℃
# 0.0 5shift수온 ℃
# 0.0 6shift수온 ℃
# 0.0 7shift수온 ℃
# 0.0 8shift수온 ℃
# 0.0 9shift수온 ℃
# 0.0 10shift수온 ℃
# 0.0 11shift수온 ℃
# 0.0 12shift수온 ℃
# 0.0 13shift수온 ℃
# 0.0 14shift수온 ℃
# 0.0 15shift수온 ℃
# 0.0 16shift수온 ℃
# 0.0 17shift수온 ℃
# 0.0 18shift수온 ℃
# 0.0 19shift수온 ℃
# 0.0 20shift수온 ℃
# 0.0 21shift수온 ℃
# 0.0 22shift수온 ℃
# 0.0 23shift수온 ℃
# 0.0 24shift수온 ℃
# 0.0 25shift수온 ℃
# 0.0 26shift수온 ℃
# 0.0 27shift수온 ℃
# 0.0 28shift수온 ℃
# 0.0 29shift수온 ℃
# 0.0 30shift수온 ℃
# 0.0 31shift수온 ℃
# 0.0 32shift수온 ℃
# 0.0 33shift수온 ℃
# 0.0 34shift수온 ℃
# 0.0 35shift수온 ℃
# 0.0 36shift수온 ℃
# 0.0 37shift수온 ℃
# 0.0 38shift수온 ℃
# 0.0 39shift수온 ℃
# 0.0 40shift수온 ℃
# 0.0 41shift수온 ℃
# 0.0 42shift수온 ℃
# 0.0 43shift수온 ℃
# 0.0 44shift수온 ℃
# 0.0 45shift수온 ℃
# 0.0 46shift수온 ℃
# 0.0 47shift수온 ℃
# 0.0 48shift수온 ℃
# 0.0 49shift수온 ℃
# 0.0 50shift수온 ℃
# 0.0 51shift수온 ℃
# 0.0 52shift수온 ℃
# 0.0 53shift수온 ℃
# 0.0 54shift수온 ℃
# 0.0 55shift수온 ℃
# 0.0 56shift수온 ℃
# 0.0 57shift수온 ℃
# 0.0 58shift수온 ℃
# 0.0 59shift수온 ℃
# 0.0 60shift수온 ℃
# 0.0 61shift수온 ℃
# 0.0 62shift수온 ℃
# 0.0 63shift수온 ℃
# 0.0 64shift수온 ℃
# 0.0 65shift수온 ℃
# 0.0 66shift수온 ℃
# 0.0 67shift수온 ℃
# 0.0 68shift수온 ℃
# 0.0 69shift수온 ℃
# 0.0 70shift수온 ℃
# 0.0 71shift수온 ℃
# 0.0 72shift수온 ℃
# 0.0 1shift수소이온농도
# 0.0 2shift수소이온농도
# 0.0 3shift수소이온농도
# 0.0 4shift수소이온농도
# 0.0 5shift수소이온농도
# 0.0 6shift수소이온농도
# 0.0 7shift수소이온농도
# 0.0 8shift수소이온농도
# 0.0 9shift수소이온농도
# 0.0 10shift수소이온농도
# 0.0 11shift수소이온농도
# 0.0 12shift수소이온농도
# 0.0 13shift수소이온농도
# 0.0 14shift수소이온농도
# 0.0 15shift수소이온농도
# 0.0 16shift수소이온농도
# 0.0 17shift수소이온농도
# 0.0 18shift수소이온농도
# 0.0 19shift수소이온농도
# 0.0 20shift수소이온농도
# 0.0 21shift수소이온농도
# 0.0 22shift수소이온농도
# 0.0 23shift수소이온농도
# 0.0 24shift수소이온농도
# 0.0 25shift수소이온농도
# 0.0 26shift수소이온농도
# 0.0 27shift수소이온농도
# 0.0 28shift수소이온농도
# 0.0 29shift수소이온농도
# 0.0 30shift수소이온농도
# 0.0 31shift수소이온농도
# 0.0 32shift수소이온농도
# 0.0 33shift수소이온농도
# 0.0 34shift수소이온농도
# 0.0 35shift수소이온농도
# 0.0 36shift수소이온농도
# 0.0 37shift수소이온농도
# 0.0 38shift수소이온농도
# 0.0 39shift수소이온농도
# 0.0 40shift수소이온농도
# 0.0 41shift수소이온농도
# 0.0 42shift수소이온농도
# 0.0 43shift수소이온농도
# 0.0 44shift수소이온농도
# 0.0 45shift수소이온농도
# 0.0 46shift수소이온농도
# 0.0 47shift수소이온농도
# 0.0 48shift수소이온농도
# 0.0 49shift수소이온농도
# 0.0 50shift수소이온농도
# 0.0 51shift수소이온농도
# 0.0 52shift수소이온농도
# 0.0 53shift수소이온농도
# 0.0 54shift수소이온농도
# 0.0 55shift수소이온농도
# 0.0 56shift수소이온농도
# 0.0 57shift수소이온농도
# 0.0 58shift수소이온농도
# 0.0 59shift수소이온농도
# 0.0 60shift수소이온농도
# 0.0 61shift수소이온농도
# 0.0 62shift수소이온농도
# 0.0 63shift수소이온농도
# 0.0 64shift수소이온농도
# 0.0 65shift수소이온농도
# 0.0 66shift수소이온농도
# 0.0 67shift수소이온농도
# 0.0 68shift수소이온농도
# 0.0 69shift수소이온농도
# 0.0 70shift수소이온농도
# 0.0 71shift수소이온농도
# 0.0 72shift수소이온농도
# 0.0 1shift전기전도도 μS/cm
# 0.0 2shift전기전도도 μS/cm
# 0.0 3shift전기전도도 μS/cm
# 0.0 4shift전기전도도 μS/cm
# 0.0 5shift전기전도도 μS/cm
# 0.0 6shift전기전도도 μS/cm
# 0.0 7shift전기전도도 μS/cm
# 0.0 8shift전기전도도 μS/cm
# 0.0 9shift전기전도도 μS/cm
# 0.0 10shift전기전도도 μS/cm
# 0.0 11shift전기전도도 μS/cm
# 0.0 12shift전기전도도 μS/cm
# 0.0 13shift전기전도도 μS/cm
# 0.0 14shift전기전도도 μS/cm
# 0.0 15shift전기전도도 μS/cm
# 0.0 16shift전기전도도 μS/cm
# 0.0 17shift전기전도도 μS/cm
# 0.0 18shift전기전도도 μS/cm
# 0.0 19shift전기전도도 μS/cm
# 0.0 20shift전기전도도 μS/cm
# 0.0 21shift전기전도도 μS/cm
# 0.0 22shift전기전도도 μS/cm
# 0.0 23shift전기전도도 μS/cm
# 0.0 24shift전기전도도 μS/cm
# 0.0 25shift전기전도도 μS/cm
# 0.0 26shift전기전도도 μS/cm
# 0.0 27shift전기전도도 μS/cm
# 0.0 28shift전기전도도 μS/cm
# 0.0 29shift전기전도도 μS/cm
# 0.0 30shift전기전도도 μS/cm
# 0.0 31shift전기전도도 μS/cm
# 0.0 32shift전기전도도 μS/cm
# 0.0 33shift전기전도도 μS/cm
# 0.0 34shift전기전도도 μS/cm
# 0.0 35shift전기전도도 μS/cm
# 0.0 36shift전기전도도 μS/cm
# 0.0 37shift전기전도도 μS/cm
# 0.0 38shift전기전도도 μS/cm
# 0.0 39shift전기전도도 μS/cm
# 0.0 40shift전기전도도 μS/cm
# 0.0 41shift전기전도도 μS/cm
# 0.0 42shift전기전도도 μS/cm
# 0.0 43shift전기전도도 μS/cm
# 0.0 44shift전기전도도 μS/cm
# 0.0 45shift전기전도도 μS/cm
# 0.0 46shift전기전도도 μS/cm
# 0.0 47shift전기전도도 μS/cm
# 0.0 48shift전기전도도 μS/cm
# 0.0 49shift전기전도도 μS/cm
# 0.0 50shift전기전도도 μS/cm
# 0.0 51shift전기전도도 μS/cm
# 0.0 52shift전기전도도 μS/cm
# 0.0 53shift전기전도도 μS/cm
# 0.0 54shift전기전도도 μS/cm
# 0.0 55shift전기전도도 μS/cm
# 0.0 56shift전기전도도 μS/cm
# 0.0 57shift전기전도도 μS/cm
# 0.0 58shift전기전도도 μS/cm
# 0.0 59shift전기전도도 μS/cm
# 0.0 60shift전기전도도 μS/cm
# 0.0 61shift전기전도도 μS/cm
# 0.0 62shift전기전도도 μS/cm
# 0.0 63shift전기전도도 μS/cm
# 0.0 64shift전기전도도 μS/cm
# 0.0 65shift전기전도도 μS/cm
# 0.0 66shift전기전도도 μS/cm
# 0.0 67shift전기전도도 μS/cm
# 0.0 68shift전기전도도 μS/cm
# 0.0 69shift전기전도도 μS/cm
# 0.0 70shift전기전도도 μS/cm
# 0.0 71shift전기전도도 μS/cm
# 0.0 72shift전기전도도 μS/cm
# 0.0 1shift용존산소 mg/L
# 0.0 2shift용존산소 mg/L
# 0.0 3shift용존산소 mg/L
# 0.0 4shift용존산소 mg/L
# 0.0 5shift용존산소 mg/L
# 0.0 6shift용존산소 mg/L
# 0.0 7shift용존산소 mg/L
# 0.0 8shift용존산소 mg/L
# 0.0 9shift용존산소 mg/L
# 0.0 10shift용존산소 mg/L
# 0.0 11shift용존산소 mg/L
# 0.0 12shift용존산소 mg/L
# 0.0 13shift용존산소 mg/L
# 0.0 14shift용존산소 mg/L
# 0.0 15shift용존산소 mg/L
# 0.0 16shift용존산소 mg/L
# 0.0 17shift용존산소 mg/L
# 0.0 18shift용존산소 mg/L
# 0.0 19shift용존산소 mg/L
# 0.0 20shift용존산소 mg/L
# 0.0 21shift용존산소 mg/L
# 0.0 22shift용존산소 mg/L
# 0.0 23shift용존산소 mg/L
# 0.0 24shift용존산소 mg/L
# 0.0 25shift용존산소 mg/L
# 0.0 26shift용존산소 mg/L
# 0.0 27shift용존산소 mg/L
# 0.0 28shift용존산소 mg/L
# 0.0 29shift용존산소 mg/L
# 0.0 30shift용존산소 mg/L
# 0.0 31shift용존산소 mg/L
# 0.0 32shift용존산소 mg/L
# 0.0 33shift용존산소 mg/L
# 0.0 34shift용존산소 mg/L
# 0.0 35shift용존산소 mg/L
# 0.0 36shift용존산소 mg/L
# 0.0 37shift용존산소 mg/L
# 0.0 38shift용존산소 mg/L
# 0.0 39shift용존산소 mg/L
# 0.0 40shift용존산소 mg/L
# 0.0 41shift용존산소 mg/L
# 0.0 42shift용존산소 mg/L
# 0.0 43shift용존산소 mg/L
# 0.0 44shift용존산소 mg/L
# 0.0 45shift용존산소 mg/L
# 0.0 46shift용존산소 mg/L
# 0.0 47shift용존산소 mg/L
# 0.0 48shift용존산소 mg/L
# 0.0 49shift용존산소 mg/L
# 0.0 50shift용존산소 mg/L
# 0.0 51shift용존산소 mg/L
# 0.0 52shift용존산소 mg/L
# 0.0 53shift용존산소 mg/L
# 0.0 54shift용존산소 mg/L
# 0.0 55shift용존산소 mg/L
# 0.0 56shift용존산소 mg/L
# 0.0 57shift용존산소 mg/L
# 0.0 58shift용존산소 mg/L
# 0.0 59shift용존산소 mg/L
# 0.0 60shift용존산소 mg/L
# 0.0 61shift용존산소 mg/L
# 0.0 62shift용존산소 mg/L
# 0.0 63shift용존산소 mg/L
# 0.0 64shift용존산소 mg/L
# 0.0 65shift용존산소 mg/L
# 0.0 66shift용존산소 mg/L
# 0.0 67shift용존산소 mg/L
# 0.0 68shift용존산소 mg/L
# 0.0 69shift용존산소 mg/L
# 0.0 70shift용존산소 mg/L
# 0.0 71shift용존산소 mg/L
# 0.0 72shift용존산소 mg/L
# 0.0 1shift탁도 NTU
# 0.0 2shift탁도 NTU
# 0.0 3shift탁도 NTU
# 0.0 4shift탁도 NTU
# 0.0 5shift탁도 NTU
# 0.0 6shift탁도 NTU
# 0.0 7shift탁도 NTU
# 0.0 8shift탁도 NTU
# 0.0 9shift탁도 NTU
# 0.0 10shift탁도 NTU
# 0.0 11shift탁도 NTU
# 0.0 12shift탁도 NTU
# 0.0 13shift탁도 NTU
# 0.0 14shift탁도 NTU
# 0.0 15shift탁도 NTU
# 0.0 16shift탁도 NTU
# 0.0 17shift탁도 NTU
# 0.0 18shift탁도 NTU
# 0.0 19shift탁도 NTU
# 0.0 20shift탁도 NTU
# 0.0 21shift탁도 NTU
# 0.0 22shift탁도 NTU
# 0.0 23shift탁도 NTU
# 0.0 24shift탁도 NTU
# 0.0 25shift탁도 NTU
# 0.0 26shift탁도 NTU
# 0.0 27shift탁도 NTU
# 0.0 28shift탁도 NTU
# 0.0 29shift탁도 NTU
# 0.0 30shift탁도 NTU
# 0.0 31shift탁도 NTU
# 0.0 32shift탁도 NTU
# 0.0 33shift탁도 NTU
# 0.0 34shift탁도 NTU
# 0.0 35shift탁도 NTU
# 0.0 36shift탁도 NTU
# 0.0 37shift탁도 NTU
# 0.0 38shift탁도 NTU
# 0.0 39shift탁도 NTU
# 0.0 40shift탁도 NTU
# 0.0 41shift탁도 NTU
# 0.0 42shift탁도 NTU
# 0.0 43shift탁도 NTU
# 0.0 44shift탁도 NTU
# 0.0 45shift탁도 NTU
# 0.0 46shift탁도 NTU
# 0.0 47shift탁도 NTU
# 0.0 48shift탁도 NTU
# 0.0 49shift탁도 NTU
# 0.0 50shift탁도 NTU
# 0.0 51shift탁도 NTU
# 0.0 52shift탁도 NTU
# 0.0 53shift탁도 NTU
# 0.0 54shift탁도 NTU
# 0.0 55shift탁도 NTU
# 0.0 56shift탁도 NTU
# 0.0 57shift탁도 NTU
# 0.0 58shift탁도 NTU
# 0.0 59shift탁도 NTU
# 0.0 60shift탁도 NTU
# 0.0 61shift탁도 NTU
# 0.0 62shift탁도 NTU
# 0.0 63shift탁도 NTU
# 0.0 64shift탁도 NTU
# 0.0 65shift탁도 NTU
# 0.0 66shift탁도 NTU
# 0.0 67shift탁도 NTU
# 0.0 68shift탁도 NTU
# 0.0 69shift탁도 NTU
# 0.0 70shift탁도 NTU
# 0.0 71shift탁도 NTU
# 0.0 72shift탁도 NTU
# 0.0 1shift총유기탄소 mg/L
# 0.0 2shift총유기탄소 mg/L
# 0.0 3shift총유기탄소 mg/L
# 0.0 4shift총유기탄소 mg/L
# 0.0 5shift총유기탄소 mg/L
# 0.01 6shift총유기탄소 mg/L
# 0.0 7shift총유기탄소 mg/L
# 0.0 8shift총유기탄소 mg/L
# 0.0 9shift총유기탄소 mg/L
# 0.0 10shift총유기탄소 mg/L
# 0.0 11shift총유기탄소 mg/L
# 0.01 12shift총유기탄소 mg/L
# 0.0 13shift총유기탄소 mg/L
# 0.0 14shift총유기탄소 mg/L
# 0.0 15shift총유기탄소 mg/L
# 0.0 16shift총유기탄소 mg/L
# 0.0 17shift총유기탄소 mg/L
# 0.0 18shift총유기탄소 mg/L
# 0.0 19shift총유기탄소 mg/L
# 0.0 20shift총유기탄소 mg/L
# 0.0 21shift총유기탄소 mg/L
# 0.0 22shift총유기탄소 mg/L
# 0.0 23shift총유기탄소 mg/L
# 0.0 24shift총유기탄소 mg/L
# 0.0 25shift총유기탄소 mg/L
# 0.0 26shift총유기탄소 mg/L
# 0.0 27shift총유기탄소 mg/L
# 0.0 28shift총유기탄소 mg/L
# 0.0 29shift총유기탄소 mg/L
# 0.0 30shift총유기탄소 mg/L
# 0.0 31shift총유기탄소 mg/L
# 0.0 32shift총유기탄소 mg/L
# 0.0 33shift총유기탄소 mg/L
# 0.0 34shift총유기탄소 mg/L
# 0.0 35shift총유기탄소 mg/L
# 0.0 36shift총유기탄소 mg/L
# 0.0 37shift총유기탄소 mg/L
# 0.0 38shift총유기탄소 mg/L
# 0.0 39shift총유기탄소 mg/L
# 0.0 40shift총유기탄소 mg/L
# 0.0 41shift총유기탄소 mg/L
# 0.0 42shift총유기탄소 mg/L
# 0.0 43shift총유기탄소 mg/L
# 0.0 44shift총유기탄소 mg/L
# 0.0 45shift총유기탄소 mg/L
# 0.0 46shift총유기탄소 mg/L
# 0.0 47shift총유기탄소 mg/L
# 0.0 48shift총유기탄소 mg/L
# 0.0 49shift총유기탄소 mg/L
# 0.0 50shift총유기탄소 mg/L
# 0.0 51shift총유기탄소 mg/L
# 0.0 52shift총유기탄소 mg/L
# 0.0 53shift총유기탄소 mg/L
# 0.0 54shift총유기탄소 mg/L
# 0.0 55shift총유기탄소 mg/L
# 0.0 56shift총유기탄소 mg/L
# 0.0 57shift총유기탄소 mg/L
# 0.0 58shift총유기탄소 mg/L
# 0.0 59shift총유기탄소 mg/L
# 0.0 60shift총유기탄소 mg/L
# 0.0 61shift총유기탄소 mg/L
# 0.0 62shift총유기탄소 mg/L
# 0.0 63shift총유기탄소 mg/L
# 0.0 64shift총유기탄소 mg/L
# 0.0 65shift총유기탄소 mg/L
# 0.0 66shift총유기탄소 mg/L
# 0.0 67shift총유기탄소 mg/L
# 0.0 68shift총유기탄소 mg/L
# 0.0 69shift총유기탄소 mg/L
# 0.0 70shift총유기탄소 mg/L
# 0.0 71shift총유기탄소 mg/L
# 0.0 72shift총유기탄소 mg/L
# 0.0 1shift총질소 mg/L
# 0.0 2shift총질소 mg/L
# 0.0 3shift총질소 mg/L
# 0.0 4shift총질소 mg/L
# 0.0 5shift총질소 mg/L
# 0.0 6shift총질소 mg/L
# 0.0 7shift총질소 mg/L
# 0.0 8shift총질소 mg/L
# 0.0 9shift총질소 mg/L
# 0.0 10shift총질소 mg/L
# 0.0 11shift총질소 mg/L
# 0.0 12shift총질소 mg/L
# 0.0 13shift총질소 mg/L
# 0.0 14shift총질소 mg/L
# 0.0 15shift총질소 mg/L
# 0.0 16shift총질소 mg/L
# 0.0 17shift총질소 mg/L
# 0.0 18shift총질소 mg/L
# 0.0 19shift총질소 mg/L
# 0.0 20shift총질소 mg/L
# 0.0 21shift총질소 mg/L
# 0.0 22shift총질소 mg/L
# 0.0 23shift총질소 mg/L
# 0.0 24shift총질소 mg/L
# 0.0 25shift총질소 mg/L
# 0.0 26shift총질소 mg/L
# 0.0 27shift총질소 mg/L
# 0.0 28shift총질소 mg/L
# 0.0 29shift총질소 mg/L
# 0.0 30shift총질소 mg/L
# 0.0 31shift총질소 mg/L
# 0.0 32shift총질소 mg/L
# 0.0 33shift총질소 mg/L
# 0.0 34shift총질소 mg/L
# 0.01 35shift총질소 mg/L
# 0.0 36shift총질소 mg/L
# 0.0 37shift총질소 mg/L
# 0.0 38shift총질소 mg/L
# 0.0 39shift총질소 mg/L
# 0.0 40shift총질소 mg/L
# 0.0 41shift총질소 mg/L
# 0.0 42shift총질소 mg/L
# 0.0 43shift총질소 mg/L
# 0.0 44shift총질소 mg/L
# 0.0 45shift총질소 mg/L
# 0.0 46shift총질소 mg/L
# 0.0 47shift총질소 mg/L
# 0.0 48shift총질소 mg/L
# 0.0 49shift총질소 mg/L
# 0.0 50shift총질소 mg/L
# 0.0 51shift총질소 mg/L
# 0.0 52shift총질소 mg/L
# 0.0 53shift총질소 mg/L
# 0.0 54shift총질소 mg/L
# 0.0 55shift총질소 mg/L
# 0.0 56shift총질소 mg/L
# 0.0 57shift총질소 mg/L
# 0.0 58shift총질소 mg/L
# 0.0 59shift총질소 mg/L
# 0.0 60shift총질소 mg/L
# 0.0 61shift총질소 mg/L
# 0.0 62shift총질소 mg/L
# 0.0 63shift총질소 mg/L
# 0.0 64shift총질소 mg/L
# 0.0 65shift총질소 mg/L
# 0.0 66shift총질소 mg/L
# 0.0 67shift총질소 mg/L
# 0.0 68shift총질소 mg/L
# 0.0 69shift총질소 mg/L
# 0.0 70shift총질소 mg/L
# 0.0 71shift총질소 mg/L
# 0.0 72shift총질소 mg/L
# 0.0 1shift총인 mg/L
# 0.0 2shift총인 mg/L
# 0.0 3shift총인 mg/L
# 0.0 4shift총인 mg/L
# 0.0 5shift총인 mg/L
# 0.0 6shift총인 mg/L
# 0.0 7shift총인 mg/L
# 0.0 8shift총인 mg/L
# 0.0 9shift총인 mg/L
# 0.0 10shift총인 mg/L
# 0.0 11shift총인 mg/L
# 0.0 12shift총인 mg/L
# 0.0 13shift총인 mg/L
# 0.0 14shift총인 mg/L
# 0.0 15shift총인 mg/L
# 0.0 16shift총인 mg/L
# 0.0 17shift총인 mg/L
# 0.0 18shift총인 mg/L
# 0.0 19shift총인 mg/L
# 0.0 20shift총인 mg/L
# 0.0 21shift총인 mg/L
# 0.0 22shift총인 mg/L
# 0.0 23shift총인 mg/L
# 0.0 24shift총인 mg/L
# 0.0 25shift총인 mg/L
# 0.0 26shift총인 mg/L
# 0.0 27shift총인 mg/L
# 0.0 28shift총인 mg/L
# 0.0 29shift총인 mg/L
# 0.0 30shift총인 mg/L
# 0.0 31shift총인 mg/L
# 0.0 32shift총인 mg/L
# 0.0 33shift총인 mg/L
# 0.0 34shift총인 mg/L
# 0.0 35shift총인 mg/L
# 0.0 36shift총인 mg/L
# 0.0 37shift총인 mg/L
# 0.0 38shift총인 mg/L
# 0.0 39shift총인 mg/L
# 0.0 40shift총인 mg/L
# 0.0 41shift총인 mg/L
# 0.0 42shift총인 mg/L
# 0.0 43shift총인 mg/L
# 0.0 44shift총인 mg/L
# 0.0 45shift총인 mg/L
# 0.0 46shift총인 mg/L
# 0.0 47shift총인 mg/L
# 0.0 48shift총인 mg/L
# 0.0 49shift총인 mg/L
# 0.0 50shift총인 mg/L
# 0.0 51shift총인 mg/L
# 0.0 52shift총인 mg/L
# 0.0 53shift총인 mg/L
# 0.0 54shift총인 mg/L
# 0.0 55shift총인 mg/L
# 0.0 56shift총인 mg/L
# 0.0 57shift총인 mg/L
# 0.0 58shift총인 mg/L
# 0.0 59shift총인 mg/L
# 0.0 60shift총인 mg/L
# 0.0 61shift총인 mg/L
# 0.0 62shift총인 mg/L
# 0.0 63shift총인 mg/L
# 0.0 64shift총인 mg/L
# 0.0 65shift총인 mg/L
# 0.0 66shift총인 mg/L
# 0.0 67shift총인 mg/L
# 0.0 68shift총인 mg/L
# 0.0 69shift총인 mg/L
# 0.0 70shift총인 mg/L
# 0.0 71shift총인 mg/L
# 0.0 72shift총인 mg/L
# 0.0 1shift상류수위(EL.m)
# 0.0 2shift상류수위(EL.m)
# 0.0 3shift상류수위(EL.m)
# 0.0 4shift상류수위(EL.m)
# 0.0 5shift상류수위(EL.m)
# 0.0 6shift상류수위(EL.m)
# 0.0 7shift상류수위(EL.m)
# 0.0 8shift상류수위(EL.m)
# 0.0 9shift상류수위(EL.m)
# 0.0 10shift상류수위(EL.m)
# 0.0 11shift상류수위(EL.m)
# 0.0 12shift상류수위(EL.m)
# 0.0 13shift상류수위(EL.m)
# 0.0 14shift상류수위(EL.m)
# 0.0 15shift상류수위(EL.m)
# 0.0 16shift상류수위(EL.m)
# 0.0 17shift상류수위(EL.m)
# 0.0 18shift상류수위(EL.m)
# 0.0 19shift상류수위(EL.m)
# 0.0 20shift상류수위(EL.m)
# 0.0 21shift상류수위(EL.m)
# 0.0 22shift상류수위(EL.m)
# 0.0 23shift상류수위(EL.m)
# 0.0 24shift상류수위(EL.m)
# 0.0 25shift상류수위(EL.m)
# 0.0 26shift상류수위(EL.m)
# 0.0 27shift상류수위(EL.m)
# 0.0 28shift상류수위(EL.m)
# 0.0 29shift상류수위(EL.m)
# 0.0 30shift상류수위(EL.m)
# 0.0 31shift상류수위(EL.m)
# 0.0 32shift상류수위(EL.m)
# 0.0 33shift상류수위(EL.m)
# 0.0 34shift상류수위(EL.m)
# 0.0 35shift상류수위(EL.m)
# 0.0 36shift상류수위(EL.m)
# 0.0 37shift상류수위(EL.m)
# 0.0 38shift상류수위(EL.m)
# 0.0 39shift상류수위(EL.m)
# 0.0 40shift상류수위(EL.m)
# 0.0 41shift상류수위(EL.m)
# 0.0 42shift상류수위(EL.m)
# 0.0 43shift상류수위(EL.m)
# 0.0 44shift상류수위(EL.m)
# 0.0 45shift상류수위(EL.m)
# 0.0 46shift상류수위(EL.m)
# 0.0 47shift상류수위(EL.m)
# 0.0 48shift상류수위(EL.m)
# 0.0 49shift상류수위(EL.m)
# 0.0 50shift상류수위(EL.m)
# 0.0 51shift상류수위(EL.m)
# 0.0 52shift상류수위(EL.m)
# 0.0 53shift상류수위(EL.m)
# 0.0 54shift상류수위(EL.m)
# 0.0 55shift상류수위(EL.m)
# 0.0 56shift상류수위(EL.m)
# 0.0 57shift상류수위(EL.m)
# 0.0 58shift상류수위(EL.m)
# 0.0 59shift상류수위(EL.m)
# 0.0 60shift상류수위(EL.m)
# 0.0 61shift상류수위(EL.m)
# 0.0 62shift상류수위(EL.m)
# 0.0 63shift상류수위(EL.m)
# 0.0 64shift상류수위(EL.m)
# 0.0 65shift상류수위(EL.m)
# 0.0 66shift상류수위(EL.m)
# 0.0 67shift상류수위(EL.m)
# 0.0 68shift상류수위(EL.m)
# 0.0 69shift상류수위(EL.m)
# 0.0 70shift상류수위(EL.m)
# 0.0 71shift상류수위(EL.m)
# 0.0 72shift상류수위(EL.m)
# 0.0 1shift방류량(㎥/s)
# 0.0 2shift방류량(㎥/s)
# 0.0 3shift방류량(㎥/s)
# 0.0 4shift방류량(㎥/s)
# 0.0 5shift방류량(㎥/s)
# 0.0 6shift방류량(㎥/s)
# 0.0 7shift방류량(㎥/s)
# 0.0 8shift방류량(㎥/s)
# 0.0 9shift방류량(㎥/s)
# 0.0 10shift방류량(㎥/s)
# 0.0 11shift방류량(㎥/s)
# 0.0 12shift방류량(㎥/s)
# 0.0 13shift방류량(㎥/s)
# 0.0 14shift방류량(㎥/s)
# 0.0 15shift방류량(㎥/s)
# 0.0 16shift방류량(㎥/s)
# 0.0 17shift방류량(㎥/s)
# 0.0 18shift방류량(㎥/s)
# 0.0 19shift방류량(㎥/s)
# 0.0 20shift방류량(㎥/s)
# 0.0 21shift방류량(㎥/s)
# 0.0 22shift방류량(㎥/s)
# 0.0 23shift방류량(㎥/s)
# 0.0 24shift방류량(㎥/s)
# 0.0 25shift방류량(㎥/s)
# 0.0 26shift방류량(㎥/s)
# 0.0 27shift방류량(㎥/s)
# 0.0 28shift방류량(㎥/s)
# 0.0 29shift방류량(㎥/s)
# 0.0 30shift방류량(㎥/s)
# 0.0 31shift방류량(㎥/s)
# 0.0 32shift방류량(㎥/s)
# 0.0 33shift방류량(㎥/s)
# 0.0 34shift방류량(㎥/s)
# 0.0 35shift방류량(㎥/s)
# 0.0 36shift방류량(㎥/s)
# 0.0 37shift방류량(㎥/s)
# 0.0 38shift방류량(㎥/s)
# 0.0 39shift방류량(㎥/s)
# 0.0 40shift방류량(㎥/s)
# 0.0 41shift방류량(㎥/s)
# 0.0 42shift방류량(㎥/s)
# 0.0 43shift방류량(㎥/s)
# 0.0 44shift방류량(㎥/s)
# 0.0 45shift방류량(㎥/s)
# 0.0 46shift방류량(㎥/s)
# 0.0 47shift방류량(㎥/s)
# 0.0 48shift방류량(㎥/s)
# 0.0 49shift방류량(㎥/s)
# 0.0 50shift방류량(㎥/s)
# 0.0 51shift방류량(㎥/s)
# 0.0 52shift방류량(㎥/s)
# 0.0 53shift방류량(㎥/s)
# 0.0 54shift방류량(㎥/s)
# 0.0 55shift방류량(㎥/s)
# 0.0 56shift방류량(㎥/s)
# 0.0 57shift방류량(㎥/s)
# 0.0 58shift방류량(㎥/s)
# 0.0 59shift방류량(㎥/s)
# 0.0 60shift방류량(㎥/s)
# 0.0 61shift방류량(㎥/s)
# 0.0 62shift방류량(㎥/s)
# 0.0 63shift방류량(㎥/s)
# 0.0 64shift방류량(㎥/s)
# 0.0 65shift방류량(㎥/s)
# 0.0 66shift방류량(㎥/s)
# 0.0 67shift방류량(㎥/s)
# 0.0 68shift방류량(㎥/s)
# 0.0 69shift방류량(㎥/s)
# 0.0 70shift방류량(㎥/s)
# 0.0 71shift방류량(㎥/s)
# 0.0 72shift방류량(㎥/s)

# %%
feature_series = pd.Series(data = estimator.feature_importances_, index = col_v)
feature_series = feature_series.sort_values(ascending = False)
sns.barplot(x = feature_series[:10], y = feature_series.index[:10], color = 'gray')
plt.show()

# %%
print('score :', estimator.score(X_test, np.log1p(y_test)))
# Out:
# score : 0.972671013568797

# %%
feature_series[:10]
# Out:
# 수소이온농도               0.403707
# 용존산소 mg/L            0.102167
# 총유기탄소 mg/L           0.032514
# 탁도 NTU               0.030738
# 총질소 mg/L             0.016505
# 1shift수온 ℃           0.015910
# 전기전도도 μS/cm          0.008874
# 35shift총질소 mg/L      0.008738
# 6shift총유기탄소 mg/L     0.008490
# 12shift총유기탄소 mg/L    0.005156
# dtype: float64

# %% [markdown]
# 피처 정규화

# %%
scaler = StandardScaler()
scaler.fit(jsb_df.loc[:, col_v])
jsb_scaled = scaler.transform(jsb_df.loc[:, col_v])

jsb_df_scaled = pd.DataFrame(data = jsb_scaled, columns = col_v)

# %%
jsb_df_scaled.head()

# %%
X_trains, X_tests, y_trains, y_tests = train_test_split(jsb_df_scaled.loc[:, col_v], jsb_df['클로로필-a mg/㎥'], random_state=42)
gb_regs = GradientBoostingRegressor(random_state=42)

parameters = {'max_depth':[5, 10, 15], 'learning_rate':[0.05, 0.1, 0.2]}

# %%
gb_grids = GridSearchCV(gb_regs, param_grid=parameters, cv=3)

# %%
gb_grids.fit(X_trains, np.log1p(y_trains))

# %%
scores_dfs = pd.DataFrame(gb_grids.cv_results_)

# %%
scores_dfs.sort_values(by=['rank_test_score'], inplace=True)
scores_dfs[['params', 'mean_test_score', 'rank_test_score']].head()

# %%
gb_grids.best_params_

# %%
estimators = gb_grids.best_estimator_

# %%
preds = estimators.predict(X_tests)

# %%
for score, name in zip(estimators.feature_importances_, col_v):
    print(round(score, 2), name)

# %%
feature_seriess = pd.Series(data = estimators.feature_importances_, index = col_v)
feature_seriess = feature_seriess.sort_values(ascending = False)
sns.barplot(x = feature_seriess[:10], y = feature_seriess.index[:10], color = 'gray')
plt.show()

# %%
print('score :', estimators.score(X_tests, np.log1p(y_tests)))

# %%
feature_series[:10]
